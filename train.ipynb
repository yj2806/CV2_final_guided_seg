# %%
""" Train TOS-Net. """
import os
os.environ['OMP_NUM_THREADS'] = "8"
from collections import OrderedDict
from datetime import datetime
import glob
import numpy as np
import argparse
import random
import json

# PyTorch includes
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.nn.functional import interpolate, sigmoid
import torch.backends.cudnn as cudnn

# Custom includes
import dataloaders.thinobject5k as thinobject5k
import dataloaders.custom_transforms as tr
import dataloaders.helpers as helpers
from layers.loss import binary_cross_entropy_loss, dice_loss, bootstrapped_cross_entopy_loss, our_loss
import networks.tosnet as tosnet

# Default settings
MODEL_NAME = 'TOSNet'
RANDOM_SEED = 1234
# Network-specific arguments
NUM_INPUTS = 4                  # input channels
NUM_CLASSES = 1                 # number of classes
BACKBONE = 'resnet50'           # backbone architecture
LR_SIZE = 512                   # size of context stream
# Training-specific arguments
NUM_THIN_SAMPLES = 4            # number of samples consisting of thin parts
NUM_NON_THIN_SAMPLES = 1        # number of samples consisting of non-thin parts
MIN_SIZE = 512                  # minimum image size allowed
MAX_SIZE = 512                 # maximum image size allowed
ROI_SIZE = 128                  # patch size for training
NUM_EPOCHS = 200                 # number of epochs for training
BATCH_SIZE = 4                  # batch size for training
SNAPSHOT = 2                   # store a model every 'snapshot'
LEARNING_RATE = 0.6e-3            # learning rate for training
WEIGHT_DECAY = 0.0005           # weight decay for training
MOMENTUM = 0.9                  # momentum for training
NUM_WORKERS = 6                 # number of workers to read daaset
RELAX_CROP = 50                 # enlarge bbox by 'relax_crop' pixels
ZERO_PAD_CROP = True            # insert zero padding when cropping
ADAPTIVE_RELAX = True           # compute 'relax_crop' adaptively?
DISPLAY = 20                    # print stats every 'display' iterations
CONTEXT_LOSS = {'bbce': 1}                      # losses for training context branch
MASK_LOSS = {'bootstrapped_ce': 1, 'dice': 1}   # losses for training mask prediction
EDGE_LOSS = {'bbce': 1, 'dice': 1}              # losses for training hr edge branch
DATASET = ['thinobject5k']      # dataset for training
LOSS_AVERAGE = 'size'           # how to average the loss
LR_SCHEDULE = 'poly'            # learning rate scheduler
BOOTSTRAPPED_RATIO = 1./16      # multiplier for determining #pixels in bootstrapping

def parse_args():
    parser = argparse.ArgumentParser(description='Training PatchNet')
    parser.add_argument('--model_name', type=str, default=MODEL_NAME)
    parser.add_argument('--random_seed', type=int, default=RANDOM_SEED)
    parser.add_argument('--num_inputs', type=int, default=NUM_INPUTS)
    parser.add_argument('--num_classes', type=int, default=NUM_CLASSES)
    parser.add_argument('--backbone', type=str, default=BACKBONE)
    parser.add_argument('--lr_size', type=int, default=LR_SIZE)
    parser.add_argument('--num_thin_samples', type=int, default=NUM_THIN_SAMPLES)
    parser.add_argument('--num_non_thin_samples', type=int, default=NUM_NON_THIN_SAMPLES)
    parser.add_argument('--min_size', type=int, default=MIN_SIZE)
    parser.add_argument('--max_size', type=int, default=MAX_SIZE)
    parser.add_argument('--roi_size', type=int, default=ROI_SIZE)
    parser.add_argument('--num_epochs', type=int, default=NUM_EPOCHS)
    parser.add_argument('--batch_size', type=int, default=BATCH_SIZE)
    parser.add_argument('--snapshot', type=int, default=SNAPSHOT)
    parser.add_argument('--lr', type=float, default=LEARNING_RATE)
    parser.add_argument('--weight_decay', type=float, default=WEIGHT_DECAY)
    parser.add_argument('--momentum', type=float, default=MOMENTUM)
    parser.add_argument('--num_workers', type=int, default=NUM_WORKERS)
    parser.add_argument('--relax_crop', type=int, default=RELAX_CROP)
    parser.add_argument('--zero_pad_crop', type=bool, default=ZERO_PAD_CROP)
    parser.add_argument('--adaptive_relax', type=bool, default=ADAPTIVE_RELAX)
    parser.add_argument('--display', type=int, default=DISPLAY)
    parser.add_argument('--context_loss', type=json.load, default=CONTEXT_LOSS)
    parser.add_argument('--mask_loss', type=json.load, default=MASK_LOSS)
    parser.add_argument('--edge_loss', type=json.load, default=EDGE_LOSS)
    parser.add_argument('--dataset', type=str, nargs='+', default=DATASET)
    parser.add_argument('--loss_average', type=str, default=LOSS_AVERAGE)
    parser.add_argument('--lr_schedule', type=str, default=LR_SCHEDULE)
    parser.add_argument('--bootstrapped_ratio', type=float, default=BOOTSTRAPPED_RATIO)
    args = parser.parse_args(args=[])
    return args

def _visualize_minibatch(sample, args):
    """Visualize a minibatch for debugging purpose."""
    import matplotlib.pyplot as plt
    inputs      = sample['concat'].to(device)
    inputs_lr   = sample['concat_lr'].to(device)
    grads       = sample['grad'].to(device)
    gts         = sample['crop_gt'].to(device)
    gts_lr      = sample['lr_gt'].to(device)
    gts_edge    = sample['crop_gt_edge'].to(device)
    # Thresholding
    gts = torch.ge(gts, 0.5).float()
    gts_lr = torch.ge(gts_lr, 0.5).float()
    gts_edge = torch.ge(gts_edge, 0.5).float()

    # Read rois and rearrange the inputs
    rois = sample['rois'].float().view(-1, 4)
    batch_ind = torch.arange(args.batch_size).float().unsqueeze(1).repeat(1, 
                    num_patch).view(-1, 1) # attach batch id
    rois = torch.cat((batch_ind, rois), dim=1).cuda()
    inputs = inputs.view(num_batch, 4, args.roi_size, args.roi_size)
    gts = gts.view(num_batch, 1, args.roi_size, args.roi_size)
    gts_edge = gts_edge.view(num_batch, 1, args.roi_size, args.roi_size)
    grads = grads.view(num_batch, 4, args.roi_size, args.roi_size)

    # Run roialign
    from torchvision.ops import RoIAlign
    roipool = RoIAlign((args.roi_size, args.roi_size), 1.0, -1).cuda()
    patches = roipool(inputs_lr, rois)

    # Convert to numpy
    inputs_lr = inputs_lr.cpu().numpy()
    gts_lr = gts_lr.cpu().numpy()
    inputs = inputs.cpu().numpy()
    gts = gts.cpu().numpy()
    gts_edge = gts_edge.cpu().numpy()
    patches = patches.cpu().numpy()
    grads = grads.cpu().numpy()

    for i in range(args.batch_size):
        # Visualize the low-resolution input
        image = inputs_lr[i, :3].transpose(1,2,0)
        gt = gts_lr[i, 0, :]
        clicks = inputs_lr[i, 3, :]
        clicks = np.float32(clicks == clicks.max())
        overlay = helpers.show_mask_and_clicks(image, gt, clicks)
        plt.figure(); plt.imshow(overlay.astype(np.uint8))
        plt.savefig('figure/train_lr_{}.jpg'.format(i))

        # Visualize the crop patches
        plt.figure()
        for j in range(num_patch):
            ind = i * args.batch_size + j
            image = inputs[ind, :3, :].transpose(1,2,0)
            gt = gts[ind, 0, :]
            clicks = inputs[ind, 3, :]
            if clicks.max() != 0:
                clicks = np.float32(clicks == clicks.max())
            overlay = helpers.show_mask_and_clicks(image, gt, clicks)
            patch = patches[ind, :3, :].transpose(1,2,0)
            edge = gts_edge[ind, 0, :]
            grad = grads[ind, 0, :]
            plt.subplot(4, num_patch, j+1)
            plt.imshow(overlay.astype(np.uint8))
            plt.subplot(4, num_patch, num_patch+j+1)
            plt.imshow(patch.astype(np.uint8))
            plt.subplot(4, num_patch, 2*num_patch+j+1)
            plt.imshow(edge.astype(np.uint8))
            plt.subplot(4, num_patch, 3*num_patch+j+1)
            plt.imshow(grad.astype(np.uint8))
        plt.savefig('images/train_patches_{}.jpg'.format(i))
    import pdb; pdb.set_trace()

if __name__ == '__main__':
    args = parse_args()
    p = OrderedDict()
    for arg in vars(args):
        print('[%s] =' % arg, getattr(args, arg))
        p[arg] = getattr(args, arg)

    # Set random seed for reproducibility
    random.seed(args.random_seed)
    torch.manual_seed(args.random_seed)
    device = torch.device('cuda')
    torch.cuda.manual_seed_all(args.random_seed)
    cudnn.enabled = True
    cudnn.benchmark = True
    cudnn.deterministic = True

    # Create directories
    save_dir_root = os.path.join(os.path.dirname(os.path.abspath("D:/Code_pytorch/Interactive_seg/111")))
    save_dir_root = os.path.join(save_dir_root, 'weights')
    runs = glob.glob(os.path.join(save_dir_root, 'run_*'))
    runs.sort(key=helpers.natural_keys)
    run_id = int(runs[-1].split('_')[-1]) + 1 if runs else 0
    save_dir = os.path.join(save_dir_root, 'run_' + str(run_id))
    if not os.path.exists(os.path.join(save_dir, 'models')):
        os.makedirs(os.path.join(save_dir, 'models'))

    # Network definition
    if args.backbone == 'resnet50':
        tosnet.lr_size = args.lr_size
        net = tosnet.tosnet_resnet50(n_inputs=args.num_inputs,
                                     n_classes=args.num_classes,
                                     os=16, pretrained='imagenet')
    else:
        raise NotImplementedError
    net.to(device)

    train_params = [{'params': tosnet.get_1x_lr_params(net), 'lr': args.lr},
                    {'params': tosnet.get_10x_lr_params(net), 'lr': args.lr * 10}]
    optimizer = optim.Adam(train_params, lr=args.lr, weight_decay=args.weight_decay)
    optimizer.zero_grad()
    p['optimizer'] = str(optimizer)

    composed_transforms = [
        tr.RandomHorizontalFlip(),
        tr.CropFromMask(
            crop_elems=['image', 'gt', 'thin', 'void_pixels'],
            relax=args.relax_crop,
            zero_pad=args.zero_pad_crop,
            adaptive_relax=args.adaptive_relax,
            prefix=''),
        tr.Resize(
            resize_elems=['image', 'gt', 'thin', 'void_pixels'],
            min_size=args.min_size,
            max_size=args.max_size),
        tr.ComputeImageGradient(elem='image'),
        tr.ExtremePoints(sigma=10, pert=5, elem='gt'),
        tr.GaussianTransform(
            tr_elems=['extreme_points'],
            mask_elem='gt',
            sigma=10,
            tr_name='points'),
        tr.RandomCrop(
            num_thin=args.num_thin_samples,
            num_non_thin=args.num_non_thin_samples,
            crop_size=args.roi_size,
            prefix='crop_',
            thin_elem='thin',
            crop_elems=['image', 'gt', 'points', 'void_pixels', 'image_grad']),
        tr.MatchROIs(crop_elem='gt', resolution=args.lr_size),
        tr.FixedResizePoints(
            resolutions={
                'extreme_points': (args.lr_size, args.lr_size)},
            mask_elem='gt',
            prefix='lr_'),
        tr.FixedResize(
            resolutions={
                'image' : (args.lr_size, args.lr_size),
                'gt'    : (args.lr_size, args.lr_size),
                'void_pixels': (args.lr_size, args.lr_size)},
            prefix='lr_'),
        tr.GaussianTransform(
            tr_elems=['lr_extreme_points'],
            mask_elem='lr_gt',
            sigma=10,
            tr_name='lr_points'),
        tr.ToImage(
            norm_elem=['crop_points', 'crop_image_grad', 'lr_points']),
        tr.ConcatInputs(
            cat_elems=['lr_image', 'lr_points'],
            cat_name='concat_lr'),
        tr.ConcatInputs(
            cat_elems=['crop_image', 'crop_points'],
            cat_name='concat'),
        tr.ConcatInputs(
            cat_elems=['crop_image', 'crop_image_grad'],
            cat_name='grad'),
        tr.ExtractEdge(mask_elems=['crop_gt']),
        tr.RemoveElements(
            rm_elems=['points', 'image', 'gt', 'void_pixels', 'thin', 'image_grad']),
        tr.ToTensor(excludes=['rois'])]
    composed_transforms_tr = transforms.Compose(composed_transforms)

    # Setup dataset
    if len(args.dataset) == 1 and args.dataset[0] == 'thinobject5k':
        db_train = thinobject5k.ThinObject5K(split='train', 
                        transform=composed_transforms_tr, use_thin=False)
    else:
        raise NotImplementedError

    p['dataset_train'] = str(db_train)
    p['transformations_train'] = [str(tran) for tran in composed_transforms_tr.transforms]

    trainloader = DataLoader(db_train, batch_size=args.batch_size, shuffle=True, \
                            num_workers=args.num_workers, drop_last=True)
    helpers.generate_param_report(os.path.join(save_dir, args.model_name + '.txt'), p)

    # Train variables
    num_img_tr = len(trainloader)
    num_patch = args.num_thin_samples + args.num_non_thin_samples
    num_batch = num_patch * args.batch_size
    print('Training network')
    net.train()
    
    # Main training loop
    for epoch in range(args.num_epochs):
        for ii, sample in enumerate(trainloader):

            ### Uncomment to visualize ###
            # _visualize_minibatch(sample, args)

            # Read inputs and groundtruths
            inputs      = sample['concat'].to(device)
            inputs_lr   = sample['concat_lr'].to(device)
            grads       = sample['grad'].to(device)
            voids       = sample['crop_void_pixels'].to(device) # NEW
            voids_lr    = sample['lr_void_pixels'].to(device) # NEW
            gts         = sample['crop_gt'].to(device)
            gts_lr      = sample['lr_gt'].to(device)
            gts_edge    = sample['crop_gt_edge'].to(device)
            # Threshold
            gts = torch.ge(gts, 0.5).float() 
            gts_lr = torch.ge(gts_lr, 0.5).float()
            gts_edge = torch.ge(gts_edge, 0.5).float()
            
            # Read rois and rearrange the inputs
            rois = sample['rois'].float().view(-1, 4)
            batch_ind = torch.arange(args.batch_size).float().unsqueeze(1).repeat(1, 
                            num_patch).view(-1, 1) # attach batch id
            rois = torch.cat((batch_ind, rois), dim=1).to(device)
            inputs = inputs.view(num_batch, 4, args.roi_size, args.roi_size)
            grads = grads.view(num_batch, 4, args.roi_size, args.roi_size)
            gts = gts.view(num_batch, 1, args.roi_size, args.roi_size)
            gts_edge = gts_edge.view(num_batch, 1, args.roi_size, args.roi_size)
            voids = voids.view(num_batch, 1, args.roi_size, args.roi_size)

            # Forward pass
            outs = net.forward(inputs, grads, inputs_lr, rois)
            outs_lr, outs, edges = outs
            outs_lr = interpolate(outs_lr, gts_lr.size()[2:], mode='bilinear',
                            align_corners=True)
            
            # Compute loss
            loss_lr = 0.0
            if 'bce' in args.context_loss:
                loss_lr += args.context_loss['bce'] * our_loss(outs_lr, 
                            gts_lr, class_balance=False, reduction='mean', 
                            average=args.loss_average, void_pixels=voids_lr)
            if 'bbce' in args.context_loss:
                loss_lr += args.context_loss['bbce'] * our_loss(outs_lr, 
                            gts_lr, class_balance=True, reduction='mean', 
                            average=args.loss_average, void_pixels=voids_lr)
            if 'bootstrapped_ce' in args.context_loss:
                loss_lr += args.context_loss['bootstrapped_ce'] * bootstrapped_cross_entopy_loss(outs_lr,
                            gts_lr, void_pixels=voids_lr, ratio=args.bootstrapped_ratio)
            if 'dice' in args.context_loss:
                loss_lr += args.context_loss['dice'] * dice_loss(torch.sigmoid(outs_lr), 
                            gts_lr, void_pixels=voids_lr)

            loss_hr = 0.0
            if 'bce' in args.mask_loss:
                loss_hr += args.mask_loss['bce'] * our_loss(outs, 
                            gts, class_balance=False, reduction='mean', 
                            average=args.loss_average, void_pixels=voids)
            if 'bbce' in args.mask_loss:
                loss_hr += args.mask_loss['bbce'] * our_loss(outs, 
                            gts, class_balance=True, reduction='mean', 
                            average=args.loss_average, void_pixels=voids)
            if 'bootstrapped_ce' in args.mask_loss:
                loss_hr += args.mask_loss['bootstrapped_ce'] * bootstrapped_cross_entopy_loss(outs,
                            gts, void_pixels=voids, ratio=args.bootstrapped_ratio)
            if 'dice' in args.mask_loss:
                loss_hr += args.mask_loss['dice'] * dice_loss(torch.sigmoid(outs), 
                            gts, void_pixels=voids)
            
            loss_edge = 0.0
            if 'bce' in args.edge_loss:
                loss_edge += args.edge_loss['bce'] * our_loss(edges, 
                            gts_edge, class_balance=False, reduction='mean', 
                            average=args.loss_average, void_pixels=None)
            if 'bbce' in args.edge_loss:
                loss_edge += args.edge_loss['bbce'] * our_loss(edges, 
                            gts_edge, class_balance=True, reduction='mean', 
                            average=args.loss_average, void_pixels=None)
            if 'bootstrapped_ce' in args.edge_loss:
                loss_edge += args.edge_loss['bootstrapped_ce'] * bootstrapped_cross_entopy_loss(edges,
                            gts_edge, void_pixels=None, ratio=args.bootstrapped_ratio)            
            if 'dice' in args.edge_loss:
                loss_edge += args.edge_loss['dice'] * dice_loss(torch.sigmoid(edges), 
                            gts_edge, void_pixels=None)
            loss = loss_lr + loss_hr + loss_edge

            # Backprop and update the weights
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            # Update learning rate
            if args.lr_schedule == 'poly':
                lr = helpers.adjust_lr_poly(optimizer, args.lr, 
                        ii+num_img_tr*epoch, ii+num_img_tr*args.num_epochs)

            # Print stuff every args.display iterations
            if ii % args.display == 0:
                print('{}, Epoch: {}/{}, Iter: {}/{}, '
                      'Loss: {}'.format(datetime.now().strftime('%b%d_%H-%M-%S'),
                        epoch+1, args.num_epochs, ii+1, num_img_tr, loss.item()))

        # Save the model
        if (epoch % args.snapshot) == args.snapshot -1:
            torch.save(net.state_dict(), os.path.join(save_dir, 'models', args.model_name + '_epoch-' + str(epoch) + '.pth'))
    print('Done training.')
# Out:
# [model_name] = TOSNet
# [random_seed] = 1234
# [num_inputs] = 4
# [num_classes] = 1
# [backbone] = resnet50
# [lr_size] = 512
# [num_thin_samples] = 4
# [num_non_thin_samples] = 1
# [min_size] = 512
# [max_size] = 512
# [roi_size] = 128
# [num_epochs] = 200
# [batch_size] = 4
# [snapshot] = 2
# [lr] = 0.0006
# [weight_decay] = 0.0005
# [momentum] = 0.9
# [num_workers] = 6
# [relax_crop] = 50
# [zero_pad_crop] = True
# [adaptive_relax] = True
# [display] = 20
# [context_loss] = {'bbce': 1}
# [mask_loss] = {'bootstrapped_ce': 1, 'dice': 1}
# [edge_loss] = {'bbce': 1, 'dice': 1}
# [dataset] = ['thinobject5k']
# [loss_average] = size
# [lr_schedule] = poly
# [bootstrapped_ratio] = 0.0625
# Constructing TOS-Net...
# #Inputs: 4
# #Classes: 4
# Output Stride: 16
# Initializing from imagenet
# Pre-trained weights not used: ['bn1.running_mean', 'bn1.running_var', 'layer1.0.bn1.running_mean', 'layer1.0.bn1.running_var', 'layer1.0.bn2.running_mean', 'layer1.0.bn2.running_var', 'layer1.0.bn3.running_mean', 'layer1.0.bn3.running_var', 'layer1.0.downsample.1.running_mean', 'layer1.0.downsample.1.running_var', 'layer1.1.bn1.running_mean', 'layer1.1.bn1.running_var', 'layer1.1.bn2.running_mean', 'layer1.1.bn2.running_var', 'layer1.1.bn3.running_mean', 'layer1.1.bn3.running_var', 'layer1.2.bn1.running_mean', 'layer1.2.bn1.running_var', 'layer1.2.bn2.running_mean', 'layer1.2.bn2.running_var', 'layer1.2.bn3.running_mean', 'layer1.2.bn3.running_var', 'layer2.0.bn1.running_mean', 'layer2.0.bn1.running_var', 'layer2.0.bn2.running_mean', 'layer2.0.bn2.running_var', 'layer2.0.bn3.running_mean', 'layer2.0.bn3.running_var', 'layer2.0.downsample.1.running_mean', 'layer2.0.downsample.1.running_var', 'layer2.1.bn1.running_mean', 'layer2.1.bn1.running_var', 'layer2.1.bn2.running_mean', 'layer2.1.bn2.running_var', 'layer2.1.bn3.running_mean', 'layer2.1.bn3.running_var', 'layer2.2.bn1.running_mean', 'layer2.2.bn1.running_var', 'layer2.2.bn2.running_mean', 'layer2.2.bn2.running_var', 'layer2.2.bn3.running_mean', 'layer2.2.bn3.running_var', 'layer2.3.bn1.running_mean', 'layer2.3.bn1.running_var', 'layer2.3.bn2.running_mean', 'layer2.3.bn2.running_var', 'layer2.3.bn3.running_mean', 'layer2.3.bn3.running_var', 'layer3.0.bn1.running_mean', 'layer3.0.bn1.running_var', 'layer3.0.bn2.running_mean', 'layer3.0.bn2.running_var', 'layer3.0.bn3.running_mean', 'layer3.0.bn3.running_var', 'layer3.0.downsample.1.running_mean', 'layer3.0.downsample.1.running_var', 'layer3.1.bn1.running_mean', 'layer3.1.bn1.running_var', 'layer3.1.bn2.running_mean', 'layer3.1.bn2.running_var', 'layer3.1.bn3.running_mean', 'layer3.1.bn3.running_var', 'layer3.2.bn1.running_mean', 'layer3.2.bn1.running_var', 'layer3.2.bn2.running_mean', 'layer3.2.bn2.running_var', 'layer3.2.bn3.running_mean', 'layer3.2.bn3.running_var', 'layer3.3.bn1.running_mean', 'layer3.3.bn1.running_var', 'layer3.3.bn2.running_mean', 'layer3.3.bn2.running_var', 'layer3.3.bn3.running_mean', 'layer3.3.bn3.running_var', 'layer3.4.bn1.running_mean', 'layer3.4.bn1.running_var', 'layer3.4.bn2.running_mean', 'layer3.4.bn2.running_var', 'layer3.4.bn3.running_mean', 'layer3.4.bn3.running_var', 'layer3.5.bn1.running_mean', 'layer3.5.bn1.running_var', 'layer3.5.bn2.running_mean', 'layer3.5.bn2.running_var', 'layer3.5.bn3.running_mean', 'layer3.5.bn3.running_var', 'layer4.0.bn1.running_mean', 'layer4.0.bn1.running_var', 'layer4.0.bn2.running_mean', 'layer4.0.bn2.running_var', 'layer4.0.bn3.running_mean', 'layer4.0.bn3.running_var', 'layer4.0.downsample.1.running_mean', 'layer4.0.downsample.1.running_var', 'layer4.1.bn1.running_mean', 'layer4.1.bn1.running_var', 'layer4.1.bn2.running_mean', 'layer4.1.bn2.running_var', 'layer4.1.bn3.running_mean', 'layer4.1.bn3.running_var', 'layer4.2.bn1.running_mean', 'layer4.2.bn1.running_var', 'layer4.2.bn2.running_mean', 'layer4.2.bn2.running_var', 'layer4.2.bn3.running_mean', 'layer4.2.bn3.running_var', 'fc.weight', 'fc.bias']
# 1111
# data\ThinObject5K\images\1026.png
# data\ThinObject5K\masks\1026.png
# data\ThinObject5K\images\1027.png
# data\ThinObject5K\masks\1027.png
# data\ThinObject5K\images\1028.png
# data\ThinObject5K\masks\1028.png
# data\ThinObject5K\images\1029.png
# data\ThinObject5K\masks\1029.png
# data\ThinObject5K\images\1030.png
# data\ThinObject5K\masks\1030.png
# data\ThinObject5K\images\1031.png
# data\ThinObject5K\masks\1031.png
# data\ThinObject5K\images\1032.png
# data\ThinObject5K\masks\1032.png
# data\ThinObject5K\images\1033.png
# data\ThinObject5K\masks\1033.png
# data\ThinObject5K\images\1034.png
# data\ThinObject5K\masks\1034.png
# data\ThinObject5K\images\1035.png
# data\ThinObject5K\masks\1035.png
# data\ThinObject5K\images\1036.png
# data\ThinObject5K\masks\1036.png
# data\ThinObject5K\images\1037.png
# data\ThinObject5K\masks\1037.png
# data\ThinObject5K\images\1038.png
# data\ThinObject5K\masks\1038.png
# data\ThinObject5K\images\1039.png
# data\ThinObject5K\masks\1039.png
# data\ThinObject5K\images\1040.png
# data\ThinObject5K\masks\1040.png
# data\ThinObject5K\images\1041.png
# data\ThinObject5K\masks\1041.png
# data\ThinObject5K\images\1042.png
# data\ThinObject5K\masks\1042.png
# data\ThinObject5K\images\1043.png
# data\ThinObject5K\masks\1043.png
# data\ThinObject5K\images\1044.png
# data\ThinObject5K\masks\1044.png
# data\ThinObject5K\images\1045.png
# data\ThinObject5K\masks\1045.png
# data\ThinObject5K\images\1046.png
# data\ThinObject5K\masks\1046.png
# data\ThinObject5K\images\1047.png
# data\ThinObject5K\masks\1047.png
# data\ThinObject5K\images\1048.png
# data\ThinObject5K\masks\1048.png
# data\ThinObject5K\images\1049.png
# data\ThinObject5K\masks\1049.png
# data\ThinObject5K\images\1050.png
# data\ThinObject5K\masks\1050.png
# data\ThinObject5K\images\1051.png
# data\ThinObject5K\masks\1051.png
# data\ThinObject5K\images\1052.png
# data\ThinObject5K\masks\1052.png
# data\ThinObject5K\images\1053.png
# data\ThinObject5K\masks\1053.png
# data\ThinObject5K\images\1054.png
# data\ThinObject5K\masks\1054.png
# data\ThinObject5K\images\1055.png
# data\ThinObject5K\masks\1055.png
# data\ThinObject5K\images\1056.png
# data\ThinObject5K\masks\1056.png
# data\ThinObject5K\images\1057.png
# data\ThinObject5K\masks\1057.png
# data\ThinObject5K\images\1058.png
# data\ThinObject5K\masks\1058.png
# data\ThinObject5K\images\1059.png
# data\ThinObject5K\masks\1059.png
# data\ThinObject5K\images\1060.png
# data\ThinObject5K\masks\1060.png
# data\ThinObject5K\images\1061.png
# data\ThinObject5K\masks\1061.png
# data\ThinObject5K\images\1062.png
# data\ThinObject5K\masks\1062.png
# data\ThinObject5K\images\1063.png
# data\ThinObject5K\masks\1063.png
# data\ThinObject5K\images\1064.png
# data\ThinObject5K\masks\1064.png
# data\ThinObject5K\images\1065.png
# data\ThinObject5K\masks\1065.png
# data\ThinObject5K\images\1066.png
# data\ThinObject5K\masks\1066.png
# data\ThinObject5K\images\1067.png
# data\ThinObject5K\masks\1067.png
# data\ThinObject5K\images\1068.png
# data\ThinObject5K\masks\1068.png
# data\ThinObject5K\images\1069.png
# data\ThinObject5K\masks\1069.png
# data\ThinObject5K\images\1070.png
# data\ThinObject5K\masks\1070.png
# data\ThinObject5K\images\1071.png
# data\ThinObject5K\masks\1071.png
# data\ThinObject5K\images\1072.png
# data\ThinObject5K\masks\1072.png
# data\ThinObject5K\images\1073.png
# data\ThinObject5K\masks\1073.png
# data\ThinObject5K\images\1074.png
# data\ThinObject5K\masks\1074.png
# data\ThinObject5K\images\1075.png
# data\ThinObject5K\masks\1075.png
# data\ThinObject5K\images\1076.png
# data\ThinObject5K\masks\1076.png
# data\ThinObject5K\images\1077.png
# data\ThinObject5K\masks\1077.png
# data\ThinObject5K\images\1078.png
# data\ThinObject5K\masks\1078.png
# data\ThinObject5K\images\1079.png
# data\ThinObject5K\masks\1079.png
# data\ThinObject5K\images\1080.png
# data\ThinObject5K\masks\1080.png
# data\ThinObject5K\images\1081.png
# data\ThinObject5K\masks\1081.png
# data\ThinObject5K\images\1082.png
# data\ThinObject5K\masks\1082.png
# data\ThinObject5K\images\1083.png
# data\ThinObject5K\masks\1083.png
# data\ThinObject5K\images\1084.png
# data\ThinObject5K\masks\1084.png
# data\ThinObject5K\images\1085.png
# data\ThinObject5K\masks\1085.png
# data\ThinObject5K\images\1086.png
# data\ThinObject5K\masks\1086.png
# data\ThinObject5K\images\1087.png
# data\ThinObject5K\masks\1087.png
# data\ThinObject5K\images\1088.png
# data\ThinObject5K\masks\1088.png
# data\ThinObject5K\images\1089.png
# data\ThinObject5K\masks\1089.png
# data\ThinObject5K\images\1090.png
# data\ThinObject5K\masks\1090.png
# data\ThinObject5K\images\1091.png
# data\ThinObject5K\masks\1091.png
# data\ThinObject5K\images\1092.png
# data\ThinObject5K\masks\1092.png
# data\ThinObject5K\images\1093.png
# data\ThinObject5K\masks\1093.png
# data\ThinObject5K\images\1094.png
# data\ThinObject5K\masks\1094.png
# data\ThinObject5K\images\1095.png
# data\ThinObject5K\masks\1095.png
# data\ThinObject5K\images\1096.png
# data\ThinObject5K\masks\1096.png
# data\ThinObject5K\images\1097.png
# data\ThinObject5K\masks\1097.png
# data\ThinObject5K\images\1098.png
# data\ThinObject5K\masks\1098.png
# data\ThinObject5K\images\1099.png
# data\ThinObject5K\masks\1099.png
# data\ThinObject5K\images\1100.png
# data\ThinObject5K\masks\1100.png
# data\ThinObject5K\images\1101.png
# data\ThinObject5K\masks\1101.png
# data\ThinObject5K\images\1102.png
# data\ThinObject5K\masks\1102.png
# data\ThinObject5K\images\1103.png
# data\ThinObject5K\masks\1103.png
# data\ThinObject5K\images\1104.png
# data\ThinObject5K\masks\1104.png
# data\ThinObject5K\images\1105.png
# data\ThinObject5K\masks\1105.png
# data\ThinObject5K\images\1106.png
# data\ThinObject5K\masks\1106.png
# data\ThinObject5K\images\1107.png
# data\ThinObject5K\masks\1107.png
# data\ThinObject5K\images\1108.png
# data\ThinObject5K\masks\1108.png
# data\ThinObject5K\images\1109.png
# data\ThinObject5K\masks\1109.png
# data\ThinObject5K\images\1110.png
# data\ThinObject5K\masks\1110.png
# data\ThinObject5K\images\1111.png
# data\ThinObject5K\masks\1111.png
# data\ThinObject5K\images\1112.png
# data\ThinObject5K\masks\1112.png
# data\ThinObject5K\images\1113.png
# data\ThinObject5K\masks\1113.png
# data\ThinObject5K\images\1114.png
# data\ThinObject5K\masks\1114.png
# data\ThinObject5K\images\1115.png
# data\ThinObject5K\masks\1115.png
# data\ThinObject5K\images\1116.png
# data\ThinObject5K\masks\1116.png
# data\ThinObject5K\images\1117.png
# data\ThinObject5K\masks\1117.png
# data\ThinObject5K\images\1118.png
# data\ThinObject5K\masks\1118.png
# data\ThinObject5K\images\1119.png
# data\ThinObject5K\masks\1119.png
# data\ThinObject5K\images\1120.png
# data\ThinObject5K\masks\1120.png
# data\ThinObject5K\images\1121.png
# data\ThinObject5K\masks\1121.png
# data\ThinObject5K\images\1122.png
# data\ThinObject5K\masks\1122.png
# data\ThinObject5K\images\1123.png
# data\ThinObject5K\masks\1123.png
# data\ThinObject5K\images\1124.png
# data\ThinObject5K\masks\1124.png
# data\ThinObject5K\images\1125.png
# data\ThinObject5K\masks\1125.png
# data\ThinObject5K\images\1126.png
# data\ThinObject5K\masks\1126.png
# data\ThinObject5K\images\1127.png
# data\ThinObject5K\masks\1127.png
# data\ThinObject5K\images\1128.png
# data\ThinObject5K\masks\1128.png
# data\ThinObject5K\images\1129.png
# data\ThinObject5K\masks\1129.png
# data\ThinObject5K\images\1130.png
# data\ThinObject5K\masks\1130.png
# data\ThinObject5K\images\1131.png
# data\ThinObject5K\masks\1131.png
# data\ThinObject5K\images\1132.png
# data\ThinObject5K\masks\1132.png
# data\ThinObject5K\images\1133.png
# data\ThinObject5K\masks\1133.png
# data\ThinObject5K\images\1134.png
# data\ThinObject5K\masks\1134.png
# data\ThinObject5K\images\1135.png
# data\ThinObject5K\masks\1135.png
# data\ThinObject5K\images\1136.png
# data\ThinObject5K\masks\1136.png
# data\ThinObject5K\images\1137.png
# data\ThinObject5K\masks\1137.png
# data\ThinObject5K\images\1138.png
# data\ThinObject5K\masks\1138.png
# data\ThinObject5K\images\1139.png
# data\ThinObject5K\masks\1139.png
# data\ThinObject5K\images\1140.png
# data\ThinObject5K\masks\1140.png
# data\ThinObject5K\images\1141.png
# data\ThinObject5K\masks\1141.png
# data\ThinObject5K\images\1142.png
# data\ThinObject5K\masks\1142.png
# data\ThinObject5K\images\1143.png
# data\ThinObject5K\masks\1143.png
# data\ThinObject5K\images\1144.png
# data\ThinObject5K\masks\1144.png
# data\ThinObject5K\images\1145.png
# data\ThinObject5K\masks\1145.png
# data\ThinObject5K\images\1146.png
# data\ThinObject5K\masks\1146.png
# data\ThinObject5K\images\1147.png
# data\ThinObject5K\masks\1147.png
# data\ThinObject5K\images\1148.png
# data\ThinObject5K\masks\1148.png
# data\ThinObject5K\images\1149.png
# data\ThinObject5K\masks\1149.png
# data\ThinObject5K\images\1150.png
# data\ThinObject5K\masks\1150.png
# data\ThinObject5K\images\1151.png
# data\ThinObject5K\masks\1151.png
# data\ThinObject5K\images\1152.png
# data\ThinObject5K\masks\1152.png
# data\ThinObject5K\images\1153.png
# data\ThinObject5K\masks\1153.png
# data\ThinObject5K\images\1154.png
# data\ThinObject5K\masks\1154.png
# data\ThinObject5K\images\1155.png
# data\ThinObject5K\masks\1155.png
# data\ThinObject5K\images\1156.png
# data\ThinObject5K\masks\1156.png
# data\ThinObject5K\images\1157.png
# data\ThinObject5K\masks\1157.png
# data\ThinObject5K\images\1158.png
# data\ThinObject5K\masks\1158.png
# data\ThinObject5K\images\1159.png
# data\ThinObject5K\masks\1159.png
# data\ThinObject5K\images\1160.png
# data\ThinObject5K\masks\1160.png
# data\ThinObject5K\images\1161.png
# data\ThinObject5K\masks\1161.png
# data\ThinObject5K\images\1162.png
# data\ThinObject5K\masks\1162.png
# data\ThinObject5K\images\1163.png
# data\ThinObject5K\masks\1163.png
# data\ThinObject5K\images\1164.png
# data\ThinObject5K\masks\1164.png
# data\ThinObject5K\images\1165.png
# data\ThinObject5K\masks\1165.png
# data\ThinObject5K\images\1166.png
# data\ThinObject5K\masks\1166.png
# data\ThinObject5K\images\1167.png
# data\ThinObject5K\masks\1167.png
# data\ThinObject5K\images\1168.png
# data\ThinObject5K\masks\1168.png
# data\ThinObject5K\images\1169.png
# data\ThinObject5K\masks\1169.png
# data\ThinObject5K\images\1170.png
# data\ThinObject5K\masks\1170.png
# data\ThinObject5K\images\1171.png
# data\ThinObject5K\masks\1171.png
# data\ThinObject5K\images\1172.png
# data\ThinObject5K\masks\1172.png
# data\ThinObject5K\images\1173.png
# data\ThinObject5K\masks\1173.png
# data\ThinObject5K\images\1174.png
# data\ThinObject5K\masks\1174.png
# data\ThinObject5K\images\1175.png
# data\ThinObject5K\masks\1175.png
# data\ThinObject5K\images\1176.png
# data\ThinObject5K\masks\1176.png
# data\ThinObject5K\images\1177.png
# data\ThinObject5K\masks\1177.png
# data\ThinObject5K\images\1178.png
# data\ThinObject5K\masks\1178.png
# data\ThinObject5K\images\1179.png
# data\ThinObject5K\masks\1179.png
# data\ThinObject5K\images\1180.png
# data\ThinObject5K\masks\1180.png
# data\ThinObject5K\images\1181.png
# data\ThinObject5K\masks\1181.png
# data\ThinObject5K\images\1182.png
# data\ThinObject5K\masks\1182.png
# data\ThinObject5K\images\1183.png
# data\ThinObject5K\masks\1183.png
# data\ThinObject5K\images\1184.png
# data\ThinObject5K\masks\1184.png
# data\ThinObject5K\images\1185.png
# data\ThinObject5K\masks\1185.png
# data\ThinObject5K\images\1186.png
# data\ThinObject5K\masks\1186.png
# data\ThinObject5K\images\1187.png
# data\ThinObject5K\masks\1187.png
# data\ThinObject5K\images\1188.png
# data\ThinObject5K\masks\1188.png
# data\ThinObject5K\images\1189.png
# data\ThinObject5K\masks\1189.png
# data\ThinObject5K\images\1190.png
# data\ThinObject5K\masks\1190.png
# data\ThinObject5K\images\1191.png
# data\ThinObject5K\masks\1191.png
# data\ThinObject5K\images\1192.png
# data\ThinObject5K\masks\1192.png
# data\ThinObject5K\images\1193.png
# data\ThinObject5K\masks\1193.png
# data\ThinObject5K\images\1194.png
# data\ThinObject5K\masks\1194.png
# data\ThinObject5K\images\1195.png
# data\ThinObject5K\masks\1195.png
# data\ThinObject5K\images\1196.png
# data\ThinObject5K\masks\1196.png
# data\ThinObject5K\images\1197.png
# data\ThinObject5K\masks\1197.png
# data\ThinObject5K\images\1198.png
# data\ThinObject5K\masks\1198.png
# data\ThinObject5K\images\1199.png
# data\ThinObject5K\masks\1199.png
# data\ThinObject5K\images\1200.png
# data\ThinObject5K\masks\1200.png
# data\ThinObject5K\images\1201.png
# data\ThinObject5K\masks\1201.png
# data\ThinObject5K\images\1202.png
# data\ThinObject5K\masks\1202.png
# data\ThinObject5K\images\1203.png
# data\ThinObject5K\masks\1203.png
# data\ThinObject5K\images\1204.png
# data\ThinObject5K\masks\1204.png
# data\ThinObject5K\images\1205.png
# data\ThinObject5K\masks\1205.png
# data\ThinObject5K\images\1206.png
# data\ThinObject5K\masks\1206.png
# data\ThinObject5K\images\1207.png
# data\ThinObject5K\masks\1207.png
# data\ThinObject5K\images\1208.png
# data\ThinObject5K\masks\1208.png
# data\ThinObject5K\images\1209.png
# data\ThinObject5K\masks\1209.png
# data\ThinObject5K\images\1210.png
# data\ThinObject5K\masks\1210.png
# data\ThinObject5K\images\1211.png
# data\ThinObject5K\masks\1211.png
# data\ThinObject5K\images\1212.png
# data\ThinObject5K\masks\1212.png
# data\ThinObject5K\images\1213.png
# data\ThinObject5K\masks\1213.png
# data\ThinObject5K\images\1214.png
# data\ThinObject5K\masks\1214.png
# data\ThinObject5K\images\1215.png
# data\ThinObject5K\masks\1215.png
# data\ThinObject5K\images\1216.png
# data\ThinObject5K\masks\1216.png
# data\ThinObject5K\images\1217.png
# data\ThinObject5K\masks\1217.png
# data\ThinObject5K\images\1218.png
# data\ThinObject5K\masks\1218.png
# data\ThinObject5K\images\1219.png
# data\ThinObject5K\masks\1219.png
# data\ThinObject5K\images\1220.png
# data\ThinObject5K\masks\1220.png
# data\ThinObject5K\images\1221.png
# data\ThinObject5K\masks\1221.png
# data\ThinObject5K\images\1222.png
# data\ThinObject5K\masks\1222.png
# data\ThinObject5K\images\1223.png
# data\ThinObject5K\masks\1223.png
# data\ThinObject5K\images\1224.png
# data\ThinObject5K\masks\1224.png
# data\ThinObject5K\images\1225.png
# data\ThinObject5K\masks\1225.png
# data\ThinObject5K\images\1226.png
# data\ThinObject5K\masks\1226.png
# data\ThinObject5K\images\1227.png
# data\ThinObject5K\masks\1227.png
# data\ThinObject5K\images\1228.png
# data\ThinObject5K\masks\1228.png
# data\ThinObject5K\images\1229.png
# data\ThinObject5K\masks\1229.png
# data\ThinObject5K\images\1230.png
# data\ThinObject5K\masks\1230.png
# data\ThinObject5K\images\1231.png
# data\ThinObject5K\masks\1231.png
# data\ThinObject5K\images\1232.png
# data\ThinObject5K\masks\1232.png
# data\ThinObject5K\images\1233.png
# data\ThinObject5K\masks\1233.png
# data\ThinObject5K\images\1234.png
# data\ThinObject5K\masks\1234.png
# data\ThinObject5K\images\1235.png
# data\ThinObject5K\masks\1235.png
# data\ThinObject5K\images\1236.png
# data\ThinObject5K\masks\1236.png
# data\ThinObject5K\images\1237.png
# data\ThinObject5K\masks\1237.png
# data\ThinObject5K\images\1238.png
# data\ThinObject5K\masks\1238.png
# data\ThinObject5K\images\1239.png
# data\ThinObject5K\masks\1239.png
# data\ThinObject5K\images\1240.png
# data\ThinObject5K\masks\1240.png
# data\ThinObject5K\images\1241.png
# data\ThinObject5K\masks\1241.png
# data\ThinObject5K\images\1242.png
# data\ThinObject5K\masks\1242.png
# data\ThinObject5K\images\1243.png
# data\ThinObject5K\masks\1243.png
# data\ThinObject5K\images\1244.png
# data\ThinObject5K\masks\1244.png
# data\ThinObject5K\images\1245.png
# data\ThinObject5K\masks\1245.png
# data\ThinObject5K\images\1246.png
# data\ThinObject5K\masks\1246.png
# data\ThinObject5K\images\1247.png
# data\ThinObject5K\masks\1247.png
# data\ThinObject5K\images\1248.png
# data\ThinObject5K\masks\1248.png
# data\ThinObject5K\images\1249.png
# data\ThinObject5K\masks\1249.png
# data\ThinObject5K\images\1250.png
# data\ThinObject5K\masks\1250.png
# data\ThinObject5K\images\1251.png
# data\ThinObject5K\masks\1251.png
# data\ThinObject5K\images\1252.png
# data\ThinObject5K\masks\1252.png
# data\ThinObject5K\images\1253.png
# data\ThinObject5K\masks\1253.png
# data\ThinObject5K\images\1254.png
# data\ThinObject5K\masks\1254.png
# data\ThinObject5K\images\1255.png
# data\ThinObject5K\masks\1255.png
# data\ThinObject5K\images\1256.png
# data\ThinObject5K\masks\1256.png
# data\ThinObject5K\images\1257.png
# data\ThinObject5K\masks\1257.png
# data\ThinObject5K\images\1258.png
# data\ThinObject5K\masks\1258.png
# data\ThinObject5K\images\1259.png
# data\ThinObject5K\masks\1259.png
# data\ThinObject5K\images\1260.png
# data\ThinObject5K\masks\1260.png
# data\ThinObject5K\images\1261.png
# data\ThinObject5K\masks\1261.png
# data\ThinObject5K\images\1262.png
# data\ThinObject5K\masks\1262.png
# data\ThinObject5K\images\1263.png
# data\ThinObject5K\masks\1263.png
# data\ThinObject5K\images\1264.png
# data\ThinObject5K\masks\1264.png
# data\ThinObject5K\images\1265.png
# data\ThinObject5K\masks\1265.png
# data\ThinObject5K\images\1266.png
# data\ThinObject5K\masks\1266.png
# data\ThinObject5K\images\1267.png
# data\ThinObject5K\masks\1267.png
# data\ThinObject5K\images\1268.png
# data\ThinObject5K\masks\1268.png
# data\ThinObject5K\images\1269.png
# data\ThinObject5K\masks\1269.png
# data\ThinObject5K\images\1270.png
# data\ThinObject5K\masks\1270.png
# data\ThinObject5K\images\1271.png
# data\ThinObject5K\masks\1271.png
# data\ThinObject5K\images\1272.png
# data\ThinObject5K\masks\1272.png
# data\ThinObject5K\images\1273.png
# data\ThinObject5K\masks\1273.png
# data\ThinObject5K\images\1274.png
# data\ThinObject5K\masks\1274.png
# data\ThinObject5K\images\1275.png
# data\ThinObject5K\masks\1275.png
# data\ThinObject5K\images\1276.png
# data\ThinObject5K\masks\1276.png
# data\ThinObject5K\images\1277.png
# data\ThinObject5K\masks\1277.png
# data\ThinObject5K\images\1278.png
# data\ThinObject5K\masks\1278.png
# data\ThinObject5K\images\1279.png
# data\ThinObject5K\masks\1279.png
# data\ThinObject5K\images\1280.png
# data\ThinObject5K\masks\1280.png
# data\ThinObject5K\images\1281.png
# data\ThinObject5K\masks\1281.png
# data\ThinObject5K\images\1282.png
# data\ThinObject5K\masks\1282.png
# data\ThinObject5K\images\1283.png
# data\ThinObject5K\masks\1283.png
# data\ThinObject5K\images\1284.png
# data\ThinObject5K\masks\1284.png
# data\ThinObject5K\images\1285.png
# data\ThinObject5K\masks\1285.png
# data\ThinObject5K\images\1286.png
# data\ThinObject5K\masks\1286.png
# data\ThinObject5K\images\1287.png
# data\ThinObject5K\masks\1287.png
# data\ThinObject5K\images\1288.png
# data\ThinObject5K\masks\1288.png
# data\ThinObject5K\images\1289.png
# data\ThinObject5K\masks\1289.png
# data\ThinObject5K\images\1290.png
# data\ThinObject5K\masks\1290.png
# data\ThinObject5K\images\1291.png
# data\ThinObject5K\masks\1291.png
# data\ThinObject5K\images\1292.png
# data\ThinObject5K\masks\1292.png
# data\ThinObject5K\images\1293.png
# data\ThinObject5K\masks\1293.png
# data\ThinObject5K\images\1294.png
# data\ThinObject5K\masks\1294.png
# data\ThinObject5K\images\1295.png
# data\ThinObject5K\masks\1295.png
# data\ThinObject5K\images\1296.png
# data\ThinObject5K\masks\1296.png
# data\ThinObject5K\images\1297.png
# data\ThinObject5K\masks\1297.png
# data\ThinObject5K\images\1298.png
# data\ThinObject5K\masks\1298.png
# data\ThinObject5K\images\1299.png
# data\ThinObject5K\masks\1299.png
# data\ThinObject5K\images\1300.png
# data\ThinObject5K\masks\1300.png
# data\ThinObject5K\images\1301.png
# data\ThinObject5K\masks\1301.png
# data\ThinObject5K\images\1302.png
# data\ThinObject5K\masks\1302.png
# data\ThinObject5K\images\1303.png
# data\ThinObject5K\masks\1303.png
# data\ThinObject5K\images\1304.png
# data\ThinObject5K\masks\1304.png
# data\ThinObject5K\images\1305.png
# data\ThinObject5K\masks\1305.png
# data\ThinObject5K\images\1306.png
# data\ThinObject5K\masks\1306.png
# data\ThinObject5K\images\1307.png
# data\ThinObject5K\masks\1307.png
# data\ThinObject5K\images\1308.png
# data\ThinObject5K\masks\1308.png
# data\ThinObject5K\images\1309.png
# data\ThinObject5K\masks\1309.png
# data\ThinObject5K\images\1310.png
# data\ThinObject5K\masks\1310.png
# data\ThinObject5K\images\1311.png
# data\ThinObject5K\masks\1311.png
# data\ThinObject5K\images\1312.png
# data\ThinObject5K\masks\1312.png
# data\ThinObject5K\images\1313.png
# data\ThinObject5K\masks\1313.png
# data\ThinObject5K\images\1314.png
# data\ThinObject5K\masks\1314.png
# data\ThinObject5K\images\1315.png
# data\ThinObject5K\masks\1315.png
# data\ThinObject5K\images\1316.png
# data\ThinObject5K\masks\1316.png
# data\ThinObject5K\images\1317.png
# data\ThinObject5K\masks\1317.png
# data\ThinObject5K\images\1318.png
# data\ThinObject5K\masks\1318.png
# data\ThinObject5K\images\1319.png
# data\ThinObject5K\masks\1319.png
# data\ThinObject5K\images\1320.png
# data\ThinObject5K\masks\1320.png
# data\ThinObject5K\images\1321.png
# data\ThinObject5K\masks\1321.png
# data\ThinObject5K\images\1322.png
# data\ThinObject5K\masks\1322.png
# data\ThinObject5K\images\1323.png
# data\ThinObject5K\masks\1323.png
# data\ThinObject5K\images\1324.png
# data\ThinObject5K\masks\1324.png
# data\ThinObject5K\images\1325.png
# data\ThinObject5K\masks\1325.png
# data\ThinObject5K\images\1326.png
# data\ThinObject5K\masks\1326.png
# data\ThinObject5K\images\1327.png
# data\ThinObject5K\masks\1327.png
# data\ThinObject5K\images\1328.png
# data\ThinObject5K\masks\1328.png
# data\ThinObject5K\images\1329.png
# data\ThinObject5K\masks\1329.png
# data\ThinObject5K\images\1330.png
# data\ThinObject5K\masks\1330.png
# data\ThinObject5K\images\1331.png
# data\ThinObject5K\masks\1331.png
# data\ThinObject5K\images\1332.png
# data\ThinObject5K\masks\1332.png
# data\ThinObject5K\images\1333.png
# data\ThinObject5K\masks\1333.png
# data\ThinObject5K\images\1334.png
# data\ThinObject5K\masks\1334.png
# data\ThinObject5K\images\1335.png
# data\ThinObject5K\masks\1335.png
# data\ThinObject5K\images\1336.png
# data\ThinObject5K\masks\1336.png
# data\ThinObject5K\images\1337.png
# data\ThinObject5K\masks\1337.png
# data\ThinObject5K\images\1338.png
# data\ThinObject5K\masks\1338.png
# data\ThinObject5K\images\1339.png
# data\ThinObject5K\masks\1339.png
# data\ThinObject5K\images\1340.png
# data\ThinObject5K\masks\1340.png
# data\ThinObject5K\images\1341.png
# data\ThinObject5K\masks\1341.png
# data\ThinObject5K\images\1342.png
# data\ThinObject5K\masks\1342.png
# data\ThinObject5K\images\1343.png
# data\ThinObject5K\masks\1343.png
# data\ThinObject5K\images\1344.png
# data\ThinObject5K\masks\1344.png
# data\ThinObject5K\images\1345.png
# data\ThinObject5K\masks\1345.png
# data\ThinObject5K\images\1346.png
# data\ThinObject5K\masks\1346.png
# data\ThinObject5K\images\1347.png
# data\ThinObject5K\masks\1347.png
# data\ThinObject5K\images\1348.png
# data\ThinObject5K\masks\1348.png
# data\ThinObject5K\images\1349.png
# data\ThinObject5K\masks\1349.png
# data\ThinObject5K\images\1350.png
# data\ThinObject5K\masks\1350.png
# data\ThinObject5K\images\1351.png
# data\ThinObject5K\masks\1351.png
# data\ThinObject5K\images\1352.png
# data\ThinObject5K\masks\1352.png
# data\ThinObject5K\images\1353.png
# data\ThinObject5K\masks\1353.png
# data\ThinObject5K\images\1354.png
# data\ThinObject5K\masks\1354.png
# data\ThinObject5K\images\1355.png
# data\ThinObject5K\masks\1355.png
# data\ThinObject5K\images\1356.png
# data\ThinObject5K\masks\1356.png
# data\ThinObject5K\images\1357.png
# data\ThinObject5K\masks\1357.png
# data\ThinObject5K\images\1358.png
# data\ThinObject5K\masks\1358.png
# data\ThinObject5K\images\1359.png
# data\ThinObject5K\masks\1359.png
# data\ThinObject5K\images\1360.png
# data\ThinObject5K\masks\1360.png
# data\ThinObject5K\images\1361.png
# data\ThinObject5K\masks\1361.png
# data\ThinObject5K\images\1362.png
# data\ThinObject5K\masks\1362.png
# data\ThinObject5K\images\1363.png
# data\ThinObject5K\masks\1363.png
# data\ThinObject5K\images\1364.png
# data\ThinObject5K\masks\1364.png
# data\ThinObject5K\images\1365.png
# data\ThinObject5K\masks\1365.png
# data\ThinObject5K\images\1366.png
# data\ThinObject5K\masks\1366.png
# data\ThinObject5K\images\1367.png
# data\ThinObject5K\masks\1367.png
# data\ThinObject5K\images\1368.png
# data\ThinObject5K\masks\1368.png
# data\ThinObject5K\images\1369.png
# data\ThinObject5K\masks\1369.png
# data\ThinObject5K\images\1370.png
# data\ThinObject5K\masks\1370.png
# data\ThinObject5K\images\1371.png
# data\ThinObject5K\masks\1371.png
# data\ThinObject5K\images\1372.png
# data\ThinObject5K\masks\1372.png
# data\ThinObject5K\images\1373.png
# data\ThinObject5K\masks\1373.png
# data\ThinObject5K\images\1374.png
# data\ThinObject5K\masks\1374.png
# data\ThinObject5K\images\1375.png
# data\ThinObject5K\masks\1375.png
# data\ThinObject5K\images\1376.png
# data\ThinObject5K\masks\1376.png
# data\ThinObject5K\images\1377.png
# data\ThinObject5K\masks\1377.png
# data\ThinObject5K\images\1378.png
# data\ThinObject5K\masks\1378.png
# data\ThinObject5K\images\1379.png
# data\ThinObject5K\masks\1379.png
# data\ThinObject5K\images\1380.png
# data\ThinObject5K\masks\1380.png
# data\ThinObject5K\images\1381.png
# data\ThinObject5K\masks\1381.png
# data\ThinObject5K\images\1382.png
# data\ThinObject5K\masks\1382.png
# data\ThinObject5K\images\1383.png
# data\ThinObject5K\masks\1383.png
# data\ThinObject5K\images\1384.png
# data\ThinObject5K\masks\1384.png
# data\ThinObject5K\images\1385.png
# data\ThinObject5K\masks\1385.png
# data\ThinObject5K\images\1386.png
# data\ThinObject5K\masks\1386.png
# data\ThinObject5K\images\1387.png
# data\ThinObject5K\masks\1387.png
# data\ThinObject5K\images\1388.png
# data\ThinObject5K\masks\1388.png
# data\ThinObject5K\images\1389.png
# data\ThinObject5K\masks\1389.png
# data\ThinObject5K\images\1390.png
# data\ThinObject5K\masks\1390.png
# data\ThinObject5K\images\1391.png
# data\ThinObject5K\masks\1391.png
# data\ThinObject5K\images\1392.png
# data\ThinObject5K\masks\1392.png
# data\ThinObject5K\images\1393.png
# data\ThinObject5K\masks\1393.png
# data\ThinObject5K\images\1394.png
# data\ThinObject5K\masks\1394.png
# data\ThinObject5K\images\1395.png
# data\ThinObject5K\masks\1395.png
# data\ThinObject5K\images\1396.png
# data\ThinObject5K\masks\1396.png
# data\ThinObject5K\images\1397.png
# data\ThinObject5K\masks\1397.png
# data\ThinObject5K\images\1398.png
# data\ThinObject5K\masks\1398.png
# data\ThinObject5K\images\1399.png
# data\ThinObject5K\masks\1399.png
# data\ThinObject5K\images\1400.png
# data\ThinObject5K\masks\1400.png
# data\ThinObject5K\images\1401.png
# data\ThinObject5K\masks\1401.png
# data\ThinObject5K\images\1402.png
# data\ThinObject5K\masks\1402.png
# data\ThinObject5K\images\1403.png
# data\ThinObject5K\masks\1403.png
# data\ThinObject5K\images\1404.png
# data\ThinObject5K\masks\1404.png
# data\ThinObject5K\images\1405.png
# data\ThinObject5K\masks\1405.png
# data\ThinObject5K\images\1406.png
# data\ThinObject5K\masks\1406.png
# data\ThinObject5K\images\1407.png
# data\ThinObject5K\masks\1407.png
# data\ThinObject5K\images\1408.png
# data\ThinObject5K\masks\1408.png
# data\ThinObject5K\images\1409.png
# data\ThinObject5K\masks\1409.png
# data\ThinObject5K\images\1410.png
# data\ThinObject5K\masks\1410.png
# data\ThinObject5K\images\1411.png
# data\ThinObject5K\masks\1411.png
# data\ThinObject5K\images\1412.png
# data\ThinObject5K\masks\1412.png
# data\ThinObject5K\images\1413.png
# data\ThinObject5K\masks\1413.png
# data\ThinObject5K\images\1414.png
# data\ThinObject5K\masks\1414.png
# data\ThinObject5K\images\1415.png
# data\ThinObject5K\masks\1415.png
# data\ThinObject5K\images\1416.png
# data\ThinObject5K\masks\1416.png
# data\ThinObject5K\images\1417.png
# data\ThinObject5K\masks\1417.png
# 4444
# ThinObject-5K dataset
# ---------------------
# #Images: 392
# #Objects: 392
# Training network
# Jan12_03-55-13, Epoch: 1/200, Iter: 1/98, Loss: 2.7944931983947754
# Jan12_03-55-21, Epoch: 1/200, Iter: 21/98, Loss: 1.9947831630706787
# Jan12_03-55-30, Epoch: 1/200, Iter: 41/98, Loss: 1.7611370086669922
# Jan12_03-55-38, Epoch: 1/200, Iter: 61/98, Loss: 1.712451457977295
# Jan12_03-55-46, Epoch: 1/200, Iter: 81/98, Loss: 1.5807205438613892
# Jan12_03-55-58, Epoch: 2/200, Iter: 1/98, Loss: 1.4210034608840942
# Jan12_03-56-06, Epoch: 2/200, Iter: 21/98, Loss: 1.737884521484375
# Jan12_03-56-14, Epoch: 2/200, Iter: 41/98, Loss: 1.7788201570510864
# Jan12_03-56-23, Epoch: 2/200, Iter: 61/98, Loss: 1.510585904121399
# Jan12_03-56-32, Epoch: 2/200, Iter: 81/98, Loss: 1.608469843864441
# Jan12_03-56-44, Epoch: 3/200, Iter: 1/98, Loss: 1.7050045728683472
# Jan12_03-56-52, Epoch: 3/200, Iter: 21/98, Loss: 1.5789400339126587
# Jan12_03-57-01, Epoch: 3/200, Iter: 41/98, Loss: 1.7229183912277222
# Jan12_03-57-09, Epoch: 3/200, Iter: 61/98, Loss: 1.647902488708496
# Jan12_03-57-18, Epoch: 3/200, Iter: 81/98, Loss: 1.3143136501312256
# Jan12_03-57-30, Epoch: 4/200, Iter: 1/98, Loss: 1.6422518491744995
# Jan12_03-57-38, Epoch: 4/200, Iter: 21/98, Loss: 1.6443003416061401
# Jan12_03-57-47, Epoch: 4/200, Iter: 41/98, Loss: 1.6818873882293701
# Jan12_03-57-56, Epoch: 4/200, Iter: 61/98, Loss: 1.7517417669296265
# Jan12_03-58-05, Epoch: 4/200, Iter: 81/98, Loss: 1.365516185760498
# Jan12_03-58-18, Epoch: 5/200, Iter: 1/98, Loss: 1.7741222381591797
# Jan12_03-58-26, Epoch: 5/200, Iter: 21/98, Loss: 1.3948372602462769
# Jan12_03-58-35, Epoch: 5/200, Iter: 41/98, Loss: 1.6918456554412842
# Jan12_03-58-44, Epoch: 5/200, Iter: 61/98, Loss: 1.6357367038726807
# Jan12_03-58-53, Epoch: 5/200, Iter: 81/98, Loss: 1.6593011617660522
# Jan12_03-59-05, Epoch: 6/200, Iter: 1/98, Loss: 1.717363715171814
# Jan12_03-59-14, Epoch: 6/200, Iter: 21/98, Loss: 1.3712189197540283
# Jan12_03-59-23, Epoch: 6/200, Iter: 41/98, Loss: 1.6132309436798096
# Jan12_03-59-31, Epoch: 6/200, Iter: 61/98, Loss: 1.4236717224121094
# Jan12_03-59-40, Epoch: 6/200, Iter: 81/98, Loss: 1.6826287508010864
# Jan12_03-59-53, Epoch: 7/200, Iter: 1/98, Loss: 1.694757342338562
# Jan12_04-00-01, Epoch: 7/200, Iter: 21/98, Loss: 1.751267433166504
# Jan12_04-00-10, Epoch: 7/200, Iter: 41/98, Loss: 1.6368792057037354
# Jan12_04-00-19, Epoch: 7/200, Iter: 61/98, Loss: 1.702169418334961
# Jan12_04-00-28, Epoch: 7/200, Iter: 81/98, Loss: 1.4708888530731201
# Jan12_04-00-40, Epoch: 8/200, Iter: 1/98, Loss: 1.4822800159454346
# Jan12_04-00-49, Epoch: 8/200, Iter: 21/98, Loss: 1.4793531894683838
# Jan12_04-00-57, Epoch: 8/200, Iter: 41/98, Loss: 1.6728854179382324
# Jan12_04-01-06, Epoch: 8/200, Iter: 61/98, Loss: 1.492734432220459
# Jan12_04-01-15, Epoch: 8/200, Iter: 81/98, Loss: 1.4660851955413818
# Jan12_04-01-28, Epoch: 9/200, Iter: 1/98, Loss: 1.5319464206695557
# Jan12_04-01-37, Epoch: 9/200, Iter: 21/98, Loss: 1.6594771146774292
# Jan12_04-01-46, Epoch: 9/200, Iter: 41/98, Loss: 1.5950603485107422
# Jan12_04-01-55, Epoch: 9/200, Iter: 61/98, Loss: 1.3975868225097656
# Jan12_04-02-03, Epoch: 9/200, Iter: 81/98, Loss: 1.5061042308807373
# Jan12_04-02-15, Epoch: 10/200, Iter: 1/98, Loss: 1.615964412689209
# Jan12_04-02-23, Epoch: 10/200, Iter: 21/98, Loss: 1.4929659366607666
# Jan12_04-02-32, Epoch: 10/200, Iter: 41/98, Loss: 1.5961241722106934
# Jan12_04-02-40, Epoch: 10/200, Iter: 61/98, Loss: 1.3705742359161377
# Jan12_04-02-49, Epoch: 10/200, Iter: 81/98, Loss: 1.4270813465118408
# Jan12_04-03-01, Epoch: 11/200, Iter: 1/98, Loss: 1.679473876953125
# Jan12_04-03-10, Epoch: 11/200, Iter: 21/98, Loss: 1.4345896244049072
# Jan12_04-03-18, Epoch: 11/200, Iter: 41/98, Loss: 1.5372178554534912
# Jan12_04-03-27, Epoch: 11/200, Iter: 61/98, Loss: 1.5367052555084229
# Jan12_04-03-36, Epoch: 11/200, Iter: 81/98, Loss: 1.6987485885620117
# Jan12_04-03-48, Epoch: 12/200, Iter: 1/98, Loss: 1.448840856552124
# Jan12_04-03-58, Epoch: 12/200, Iter: 21/98, Loss: 1.8386809825897217
# Jan12_04-04-07, Epoch: 12/200, Iter: 41/98, Loss: 1.6548961400985718
# Jan12_04-04-16, Epoch: 12/200, Iter: 61/98, Loss: 1.5126407146453857
# Jan12_04-04-25, Epoch: 12/200, Iter: 81/98, Loss: 1.6032116413116455
# Jan12_04-04-37, Epoch: 13/200, Iter: 1/98, Loss: 1.5227982997894287
# Jan12_04-04-46, Epoch: 13/200, Iter: 21/98, Loss: 1.656511664390564
# Jan12_04-04-55, Epoch: 13/200, Iter: 41/98, Loss: 1.5594013929367065
# Jan12_04-05-04, Epoch: 13/200, Iter: 61/98, Loss: 1.3932998180389404
# Jan12_04-05-12, Epoch: 13/200, Iter: 81/98, Loss: 1.3779749870300293
# Jan12_04-05-24, Epoch: 14/200, Iter: 1/98, Loss: 1.5583219528198242
# Jan12_04-05-33, Epoch: 14/200, Iter: 21/98, Loss: 1.507970929145813
# Jan12_04-05-41, Epoch: 14/200, Iter: 41/98, Loss: 1.3835303783416748
# Jan12_04-05-50, Epoch: 14/200, Iter: 61/98, Loss: 1.7506407499313354
# Jan12_04-05-59, Epoch: 14/200, Iter: 81/98, Loss: 1.475801944732666
# Jan12_04-06-11, Epoch: 15/200, Iter: 1/98, Loss: 1.479383945465088
# Jan12_04-06-19, Epoch: 15/200, Iter: 21/98, Loss: 1.5135424137115479
# Jan12_04-06-28, Epoch: 15/200, Iter: 41/98, Loss: 1.3231086730957031
# Jan12_04-06-37, Epoch: 15/200, Iter: 61/98, Loss: 1.6169261932373047
# Jan12_04-06-45, Epoch: 15/200, Iter: 81/98, Loss: 1.528796911239624
# Jan12_04-06-57, Epoch: 16/200, Iter: 1/98, Loss: 1.4412727355957031
# Jan12_04-07-06, Epoch: 16/200, Iter: 21/98, Loss: 1.7432212829589844
# Jan12_04-07-15, Epoch: 16/200, Iter: 41/98, Loss: 1.4904110431671143
# Jan12_04-07-24, Epoch: 16/200, Iter: 61/98, Loss: 1.2540695667266846
# Jan12_04-07-33, Epoch: 16/200, Iter: 81/98, Loss: 1.6325657367706299
# Jan12_04-07-45, Epoch: 17/200, Iter: 1/98, Loss: 1.7472658157348633
# Jan12_04-07-54, Epoch: 17/200, Iter: 21/98, Loss: 1.5492807626724243
# Jan12_04-08-03, Epoch: 17/200, Iter: 41/98, Loss: 1.5302846431732178
# Jan12_04-08-12, Epoch: 17/200, Iter: 61/98, Loss: 1.4160889387130737
# Jan12_04-08-21, Epoch: 17/200, Iter: 81/98, Loss: 1.2279281616210938
# Jan12_04-08-33, Epoch: 18/200, Iter: 1/98, Loss: 1.4865565299987793
# Jan12_04-08-42, Epoch: 18/200, Iter: 21/98, Loss: 1.5265147686004639
# Jan12_04-08-51, Epoch: 18/200, Iter: 41/98, Loss: 1.7581042051315308
# Jan12_04-09-00, Epoch: 18/200, Iter: 61/98, Loss: 1.662898302078247
# Jan12_04-09-09, Epoch: 18/200, Iter: 81/98, Loss: 1.7931938171386719
# Jan12_04-09-22, Epoch: 19/200, Iter: 1/98, Loss: 1.5653008222579956
# Jan12_04-09-31, Epoch: 19/200, Iter: 21/98, Loss: 1.2688384056091309
# Jan12_04-09-39, Epoch: 19/200, Iter: 41/98, Loss: 1.597535252571106
# Jan12_04-09-48, Epoch: 19/200, Iter: 61/98, Loss: 1.4487472772598267
# Jan12_04-09-57, Epoch: 19/200, Iter: 81/98, Loss: 1.4766907691955566
# Jan12_04-10-10, Epoch: 20/200, Iter: 1/98, Loss: 1.5842796564102173
# Jan12_04-10-19, Epoch: 20/200, Iter: 21/98, Loss: 1.5167081356048584
# Jan12_04-10-28, Epoch: 20/200, Iter: 41/98, Loss: 1.4581408500671387
# Jan12_04-10-37, Epoch: 20/200, Iter: 61/98, Loss: 1.7372322082519531
# Jan12_04-10-46, Epoch: 20/200, Iter: 81/98, Loss: 1.7036625146865845
# Jan12_04-10-58, Epoch: 21/200, Iter: 1/98, Loss: 1.4758527278900146
# Jan12_04-11-07, Epoch: 21/200, Iter: 21/98, Loss: 1.727815866470337
# Jan12_04-11-16, Epoch: 21/200, Iter: 41/98, Loss: 1.677507758140564
# Jan12_04-11-25, Epoch: 21/200, Iter: 61/98, Loss: 1.596841812133789
# Jan12_04-11-34, Epoch: 21/200, Iter: 81/98, Loss: 1.520471453666687
# Jan12_04-11-46, Epoch: 22/200, Iter: 1/98, Loss: 1.4099831581115723
# Jan12_04-11-55, Epoch: 22/200, Iter: 21/98, Loss: 1.9030380249023438
# Jan12_04-12-04, Epoch: 22/200, Iter: 41/98, Loss: 1.468098759651184
# Jan12_04-12-13, Epoch: 22/200, Iter: 61/98, Loss: 1.175403356552124
# Jan12_04-12-22, Epoch: 22/200, Iter: 81/98, Loss: 1.6902239322662354
# Jan12_04-12-35, Epoch: 23/200, Iter: 1/98, Loss: 1.754082441329956
# Jan12_04-12-44, Epoch: 23/200, Iter: 21/98, Loss: 1.6707379817962646
# Jan12_04-12-53, Epoch: 23/200, Iter: 41/98, Loss: 1.7426879405975342
# Jan12_04-13-02, Epoch: 23/200, Iter: 61/98, Loss: 1.5689685344696045
# Jan12_04-13-11, Epoch: 23/200, Iter: 81/98, Loss: 1.6669340133666992
# Jan12_04-13-23, Epoch: 24/200, Iter: 1/98, Loss: 1.7245060205459595
# Jan12_04-13-32, Epoch: 24/200, Iter: 21/98, Loss: 1.5315072536468506
# Jan12_04-13-41, Epoch: 24/200, Iter: 41/98, Loss: 1.6251411437988281
# Jan12_04-13-50, Epoch: 24/200, Iter: 61/98, Loss: 1.4304137229919434
# Jan12_04-13-59, Epoch: 24/200, Iter: 81/98, Loss: 1.5984001159667969
# Jan12_04-14-12, Epoch: 25/200, Iter: 1/98, Loss: 1.7046141624450684
# Jan12_04-14-21, Epoch: 25/200, Iter: 21/98, Loss: 1.4277228116989136
# Jan12_04-14-30, Epoch: 25/200, Iter: 41/98, Loss: 1.6552796363830566
# Jan12_04-14-39, Epoch: 25/200, Iter: 61/98, Loss: 1.558020830154419
# Jan12_04-14-48, Epoch: 25/200, Iter: 81/98, Loss: 1.7505079507827759
# Jan12_04-15-00, Epoch: 26/200, Iter: 1/98, Loss: 1.3692259788513184
# Jan12_04-15-09, Epoch: 26/200, Iter: 21/98, Loss: 1.627084732055664
# Jan12_04-15-18, Epoch: 26/200, Iter: 41/98, Loss: 1.4681200981140137
# Jan12_04-15-27, Epoch: 26/200, Iter: 61/98, Loss: 1.4405457973480225
# Jan12_04-15-36, Epoch: 26/200, Iter: 81/98, Loss: 1.393843173980713
# Jan12_04-15-49, Epoch: 27/200, Iter: 1/98, Loss: 1.342010259628296
# Jan12_04-15-58, Epoch: 27/200, Iter: 21/98, Loss: 1.7635319232940674
# Jan12_04-16-07, Epoch: 27/200, Iter: 41/98, Loss: 1.3228633403778076
# Jan12_04-16-16, Epoch: 27/200, Iter: 61/98, Loss: 1.4974641799926758
# Jan12_04-16-25, Epoch: 27/200, Iter: 81/98, Loss: 1.6585025787353516
# Jan12_04-16-37, Epoch: 28/200, Iter: 1/98, Loss: 1.4823272228240967
# Jan12_04-16-46, Epoch: 28/200, Iter: 21/98, Loss: 1.5142018795013428
# Jan12_04-16-55, Epoch: 28/200, Iter: 41/98, Loss: 1.6155049800872803
# Jan12_04-17-04, Epoch: 28/200, Iter: 61/98, Loss: 1.7122278213500977
# Jan12_04-17-12, Epoch: 28/200, Iter: 81/98, Loss: 1.1678591966629028
# Jan12_04-17-25, Epoch: 29/200, Iter: 1/98, Loss: 1.370739221572876
# Jan12_04-17-33, Epoch: 29/200, Iter: 21/98, Loss: 1.4854488372802734
# Jan12_04-17-42, Epoch: 29/200, Iter: 41/98, Loss: 1.728264570236206
# Jan12_04-17-51, Epoch: 29/200, Iter: 61/98, Loss: 1.4877681732177734
# Jan12_04-18-00, Epoch: 29/200, Iter: 81/98, Loss: 1.818375825881958
# Jan12_04-18-12, Epoch: 30/200, Iter: 1/98, Loss: 1.4090968370437622
# Jan12_04-18-20, Epoch: 30/200, Iter: 21/98, Loss: 1.6127701997756958
# Jan12_04-18-29, Epoch: 30/200, Iter: 41/98, Loss: 1.390504240989685
# Jan12_04-18-38, Epoch: 30/200, Iter: 61/98, Loss: 1.4083096981048584
# Jan12_04-18-47, Epoch: 30/200, Iter: 81/98, Loss: 1.7993502616882324
# Jan12_04-18-59, Epoch: 31/200, Iter: 1/98, Loss: 1.6776237487792969
# Jan12_04-19-08, Epoch: 31/200, Iter: 21/98, Loss: 1.4881012439727783
# Jan12_04-19-17, Epoch: 31/200, Iter: 41/98, Loss: 1.6677683591842651
# Jan12_04-19-26, Epoch: 31/200, Iter: 61/98, Loss: 1.610442876815796
# Jan12_04-19-35, Epoch: 31/200, Iter: 81/98, Loss: 1.2704927921295166
# Jan12_04-19-48, Epoch: 32/200, Iter: 1/98, Loss: 1.5967581272125244
# Jan12_04-19-57, Epoch: 32/200, Iter: 21/98, Loss: 1.5874624252319336
# Jan12_04-20-06, Epoch: 32/200, Iter: 41/98, Loss: 1.540818214416504
# Jan12_04-20-15, Epoch: 32/200, Iter: 61/98, Loss: 1.5823471546173096
# Jan12_04-20-24, Epoch: 32/200, Iter: 81/98, Loss: 1.4997978210449219
# Jan12_04-20-36, Epoch: 33/200, Iter: 1/98, Loss: 1.4297049045562744
# Jan12_04-20-45, Epoch: 33/200, Iter: 21/98, Loss: 1.5583593845367432
# Jan12_04-20-54, Epoch: 33/200, Iter: 41/98, Loss: 1.5771408081054688
# Jan12_04-21-03, Epoch: 33/200, Iter: 61/98, Loss: 1.4901989698410034
# Jan12_04-21-12, Epoch: 33/200, Iter: 81/98, Loss: 1.4398102760314941
# Jan12_04-21-24, Epoch: 34/200, Iter: 1/98, Loss: 1.3605914115905762
# Jan12_04-21-33, Epoch: 34/200, Iter: 21/98, Loss: 1.5443029403686523
# Jan12_04-21-42, Epoch: 34/200, Iter: 41/98, Loss: 1.5035840272903442
# Jan12_04-21-51, Epoch: 34/200, Iter: 61/98, Loss: 1.4839388132095337
# Jan12_04-22-00, Epoch: 34/200, Iter: 81/98, Loss: 1.5144964456558228
# Jan12_04-22-12, Epoch: 35/200, Iter: 1/98, Loss: 1.636941909790039
# Jan12_04-22-20, Epoch: 35/200, Iter: 21/98, Loss: 1.5968350172042847
# Jan12_04-22-29, Epoch: 35/200, Iter: 41/98, Loss: 1.4143056869506836
# Jan12_04-22-38, Epoch: 35/200, Iter: 61/98, Loss: 1.5880906581878662
# Jan12_04-22-47, Epoch: 35/200, Iter: 81/98, Loss: 1.45982027053833
# Jan12_04-22-59, Epoch: 36/200, Iter: 1/98, Loss: 1.4731736183166504
# Jan12_04-23-08, Epoch: 36/200, Iter: 21/98, Loss: 1.5774023532867432
# Jan12_04-23-16, Epoch: 36/200, Iter: 41/98, Loss: 1.4413847923278809
# Jan12_04-23-25, Epoch: 36/200, Iter: 61/98, Loss: 1.4094581604003906
# Jan12_04-23-34, Epoch: 36/200, Iter: 81/98, Loss: 1.5882534980773926
# Jan12_04-23-46, Epoch: 37/200, Iter: 1/98, Loss: 1.8185367584228516
# Jan12_04-23-55, Epoch: 37/200, Iter: 21/98, Loss: 1.6229616403579712
# Jan12_04-24-04, Epoch: 37/200, Iter: 41/98, Loss: 1.4266839027404785
# Jan12_04-24-13, Epoch: 37/200, Iter: 61/98, Loss: 1.5077576637268066
# Jan12_04-24-22, Epoch: 37/200, Iter: 81/98, Loss: 1.3120193481445312
# Jan12_04-24-33, Epoch: 38/200, Iter: 1/98, Loss: 1.57891845703125
# Jan12_04-24-42, Epoch: 38/200, Iter: 21/98, Loss: 1.4317514896392822
# Jan12_04-24-51, Epoch: 38/200, Iter: 41/98, Loss: 1.5435245037078857
# Jan12_04-25-00, Epoch: 38/200, Iter: 61/98, Loss: 1.5660276412963867
# Jan12_04-25-09, Epoch: 38/200, Iter: 81/98, Loss: 1.629622459411621
# Jan12_04-25-21, Epoch: 39/200, Iter: 1/98, Loss: 1.3761014938354492
# Jan12_04-25-30, Epoch: 39/200, Iter: 21/98, Loss: 1.449500322341919
# Jan12_04-25-38, Epoch: 39/200, Iter: 41/98, Loss: 1.798341989517212
# Jan12_04-25-47, Epoch: 39/200, Iter: 61/98, Loss: 1.4155354499816895
# Jan12_04-25-56, Epoch: 39/200, Iter: 81/98, Loss: 1.2516242265701294
# Jan12_04-26-08, Epoch: 40/200, Iter: 1/98, Loss: 1.5954468250274658
# Jan12_04-26-17, Epoch: 40/200, Iter: 21/98, Loss: 1.370051383972168
# Jan12_04-26-26, Epoch: 40/200, Iter: 41/98, Loss: 1.5609655380249023
# Jan12_04-26-35, Epoch: 40/200, Iter: 61/98, Loss: 1.3675771951675415
# Jan12_04-26-43, Epoch: 40/200, Iter: 81/98, Loss: 1.6314136981964111
# Jan12_04-26-56, Epoch: 41/200, Iter: 1/98, Loss: 1.5870566368103027
# Jan12_04-27-04, Epoch: 41/200, Iter: 21/98, Loss: 1.5285377502441406
# Jan12_04-27-13, Epoch: 41/200, Iter: 41/98, Loss: 1.561699628829956
# Jan12_04-27-22, Epoch: 41/200, Iter: 61/98, Loss: 1.4265084266662598
# Jan12_04-27-31, Epoch: 41/200, Iter: 81/98, Loss: 1.6249167919158936
# Jan12_04-27-43, Epoch: 42/200, Iter: 1/98, Loss: 1.3419708013534546
# Jan12_04-27-51, Epoch: 42/200, Iter: 21/98, Loss: 1.574715495109558
# Jan12_04-28-00, Epoch: 42/200, Iter: 41/98, Loss: 1.574068307876587
# Jan12_04-28-09, Epoch: 42/200, Iter: 61/98, Loss: 1.503251314163208
# Jan12_04-28-19, Epoch: 42/200, Iter: 81/98, Loss: 1.435712218284607
# Jan12_04-28-33, Epoch: 43/200, Iter: 1/98, Loss: 1.5001899003982544
# Jan12_04-28-42, Epoch: 43/200, Iter: 21/98, Loss: 1.400107979774475
# Jan12_04-28-51, Epoch: 43/200, Iter: 41/98, Loss: 1.5331830978393555
# Jan12_04-29-00, Epoch: 43/200, Iter: 61/98, Loss: 1.508544921875
# Jan12_04-29-09, Epoch: 43/200, Iter: 81/98, Loss: 1.4518004655838013
# Jan12_04-29-21, Epoch: 44/200, Iter: 1/98, Loss: 1.5366132259368896
# Jan12_04-29-30, Epoch: 44/200, Iter: 21/98, Loss: 1.3541529178619385
# Jan12_04-29-39, Epoch: 44/200, Iter: 41/98, Loss: 1.3097937107086182
# Jan12_04-29-48, Epoch: 44/200, Iter: 61/98, Loss: 1.5677368640899658
# Jan12_04-29-57, Epoch: 44/200, Iter: 81/98, Loss: 1.2278516292572021
# Jan12_04-30-10, Epoch: 45/200, Iter: 1/98, Loss: 1.5861876010894775
# Jan12_04-30-19, Epoch: 45/200, Iter: 21/98, Loss: 1.485990285873413
# Jan12_04-30-27, Epoch: 45/200, Iter: 41/98, Loss: 1.439525842666626
# Jan12_04-30-36, Epoch: 45/200, Iter: 61/98, Loss: 1.6620409488677979
# Jan12_04-30-45, Epoch: 45/200, Iter: 81/98, Loss: 1.4325438737869263
# Jan12_04-30-58, Epoch: 46/200, Iter: 1/98, Loss: 1.4126625061035156
# Jan12_04-31-07, Epoch: 46/200, Iter: 21/98, Loss: 1.5571262836456299
# Jan12_04-31-16, Epoch: 46/200, Iter: 41/98, Loss: 1.4445439577102661
# Jan12_04-31-25, Epoch: 46/200, Iter: 61/98, Loss: 1.3935980796813965
# Jan12_04-31-35, Epoch: 46/200, Iter: 81/98, Loss: 1.0737789869308472
# Jan12_04-31-47, Epoch: 47/200, Iter: 1/98, Loss: 1.2305266857147217
# Jan12_04-31-56, Epoch: 47/200, Iter: 21/98, Loss: 1.4202895164489746
# Jan12_04-32-05, Epoch: 47/200, Iter: 41/98, Loss: 1.3459522724151611
# Jan12_04-32-14, Epoch: 47/200, Iter: 61/98, Loss: 1.2557239532470703
# Jan12_04-32-23, Epoch: 47/200, Iter: 81/98, Loss: 1.525420904159546
# Jan12_04-32-35, Epoch: 48/200, Iter: 1/98, Loss: 1.5840773582458496
# Jan12_04-32-44, Epoch: 48/200, Iter: 21/98, Loss: 1.5881332159042358
# Jan12_04-32-54, Epoch: 48/200, Iter: 41/98, Loss: 1.5052449703216553
# Jan12_04-33-03, Epoch: 48/200, Iter: 61/98, Loss: 1.0639103651046753
# Jan12_04-33-12, Epoch: 48/200, Iter: 81/98, Loss: 1.611048936843872
# Jan12_04-33-26, Epoch: 49/200, Iter: 1/98, Loss: 1.5551838874816895
# Jan12_04-33-35, Epoch: 49/200, Iter: 21/98, Loss: 1.5011805295944214
# Jan12_04-33-44, Epoch: 49/200, Iter: 41/98, Loss: 1.411799669265747
# Jan12_04-33-53, Epoch: 49/200, Iter: 61/98, Loss: 1.3791172504425049
# Jan12_04-34-02, Epoch: 49/200, Iter: 81/98, Loss: 1.358543872833252
# Jan12_04-34-14, Epoch: 50/200, Iter: 1/98, Loss: 1.4577821493148804
# Jan12_04-34-24, Epoch: 50/200, Iter: 21/98, Loss: 1.277308464050293
# Jan12_04-34-33, Epoch: 50/200, Iter: 41/98, Loss: 1.6032130718231201
# Jan12_04-34-42, Epoch: 50/200, Iter: 61/98, Loss: 1.6773486137390137
# Jan12_04-34-51, Epoch: 50/200, Iter: 81/98, Loss: 1.5638024806976318
# Jan12_04-35-04, Epoch: 51/200, Iter: 1/98, Loss: 1.6497441530227661
# Jan12_04-35-13, Epoch: 51/200, Iter: 21/98, Loss: 1.3278053998947144
# Jan12_04-35-22, Epoch: 51/200, Iter: 41/98, Loss: 1.1763427257537842
# Jan12_04-35-30, Epoch: 51/200, Iter: 61/98, Loss: 1.4644103050231934
# Jan12_04-35-39, Epoch: 51/200, Iter: 81/98, Loss: 1.5520024299621582
# Jan12_04-35-51, Epoch: 52/200, Iter: 1/98, Loss: 1.2854535579681396
# Jan12_04-36-00, Epoch: 52/200, Iter: 21/98, Loss: 1.3054234981536865
# Jan12_04-36-09, Epoch: 52/200, Iter: 41/98, Loss: 1.5424025058746338
# Jan12_04-36-18, Epoch: 52/200, Iter: 61/98, Loss: 1.3242180347442627
# Jan12_04-36-27, Epoch: 52/200, Iter: 81/98, Loss: 1.2512919902801514
# ...
# Jan12_04-37-26, Epoch: 54/200, Iter: 1/98, Loss: 1.3402063846588135
# Jan12_04-37-35, Epoch: 54/200, Iter: 21/98, Loss: 1.3380587100982666
# Jan12_04-37-43, Epoch: 54/200, Iter: 41/98, Loss: 1.4675040245056152
# Jan12_04-37-52, Epoch: 54/200, Iter: 61/98, Loss: 1.6226147413253784
# Jan12_04-38-01, Epoch: 54/200, Iter: 81/98, Loss: 1.4525949954986572
# Jan12_04-38-13, Epoch: 55/200, Iter: 1/98, Loss: 1.0918843746185303
# Jan12_04-38-21, Epoch: 55/200, Iter: 21/98, Loss: 1.7363269329071045
# Jan12_04-38-30, Epoch: 55/200, Iter: 41/98, Loss: 1.483027696609497
# Jan12_04-38-38, Epoch: 55/200, Iter: 61/98, Loss: 1.5652848482131958
# Jan12_04-38-47, Epoch: 55/200, Iter: 81/98, Loss: 1.059887170791626
# Jan12_04-38-59, Epoch: 56/200, Iter: 1/98, Loss: 1.5892555713653564
# Jan12_04-39-07, Epoch: 56/200, Iter: 21/98, Loss: 1.2793928384780884
# Jan12_04-39-16, Epoch: 56/200, Iter: 41/98, Loss: 1.4644240140914917
# Jan12_04-39-25, Epoch: 56/200, Iter: 61/98, Loss: 1.6406919956207275
# Jan12_04-39-34, Epoch: 56/200, Iter: 81/98, Loss: 1.6582974195480347
# Jan12_04-39-47, Epoch: 57/200, Iter: 1/98, Loss: 1.5325019359588623
# Jan12_04-39-55, Epoch: 57/200, Iter: 21/98, Loss: 1.4348262548446655
# Jan12_04-40-04, Epoch: 57/200, Iter: 41/98, Loss: 1.2716811895370483
# Jan12_04-40-13, Epoch: 57/200, Iter: 61/98, Loss: 1.4190661907196045
# Jan12_04-40-22, Epoch: 57/200, Iter: 81/98, Loss: 1.2952206134796143
# Jan12_04-40-34, Epoch: 58/200, Iter: 1/98, Loss: 1.5504841804504395
# Jan12_04-40-43, Epoch: 58/200, Iter: 21/98, Loss: 1.4087636470794678
# Jan12_04-40-51, Epoch: 58/200, Iter: 41/98, Loss: 1.4483859539031982
# Jan12_04-41-00, Epoch: 58/200, Iter: 61/98, Loss: 1.308558464050293
# Jan12_04-41-08, Epoch: 58/200, Iter: 81/98, Loss: 1.374145269393921
# Jan12_04-41-20, Epoch: 59/200, Iter: 1/98, Loss: 1.5532175302505493
# Jan12_04-41-28, Epoch: 59/200, Iter: 21/98, Loss: 1.5049207210540771
# Jan12_04-41-37, Epoch: 59/200, Iter: 41/98, Loss: 1.3874549865722656
# Jan12_04-41-45, Epoch: 59/200, Iter: 61/98, Loss: 1.3944822549819946
# Jan12_04-41-54, Epoch: 59/200, Iter: 81/98, Loss: 1.5482730865478516
# Jan12_04-42-05, Epoch: 60/200, Iter: 1/98, Loss: 1.1967637538909912
# Jan12_04-42-14, Epoch: 60/200, Iter: 21/98, Loss: 1.4632270336151123
# Jan12_04-42-22, Epoch: 60/200, Iter: 41/98, Loss: 1.1014994382858276
# Jan12_04-42-31, Epoch: 60/200, Iter: 61/98, Loss: 1.3497302532196045
# Jan12_04-42-39, Epoch: 60/200, Iter: 81/98, Loss: 1.6128720045089722
# Jan12_04-42-51, Epoch: 61/200, Iter: 1/98, Loss: 1.453474998474121
# Jan12_04-42-59, Epoch: 61/200, Iter: 21/98, Loss: 1.5583608150482178
# Jan12_04-43-08, Epoch: 61/200, Iter: 41/98, Loss: 1.4839558601379395
# Jan12_04-43-16, Epoch: 61/200, Iter: 61/98, Loss: 1.4235039949417114
# Jan12_04-43-25, Epoch: 61/200, Iter: 81/98, Loss: 1.5470070838928223
# Jan12_04-43-36, Epoch: 62/200, Iter: 1/98, Loss: 1.6808069944381714
# Jan12_04-43-45, Epoch: 62/200, Iter: 21/98, Loss: 1.5611891746520996
# Jan12_04-43-53, Epoch: 62/200, Iter: 41/98, Loss: 1.6696159839630127
# Jan12_04-44-01, Epoch: 62/200, Iter: 61/98, Loss: 1.5054447650909424
# Jan12_04-44-10, Epoch: 62/200, Iter: 81/98, Loss: 1.5936613082885742
# Jan12_04-44-22, Epoch: 63/200, Iter: 1/98, Loss: 1.6138505935668945
# Jan12_04-44-30, Epoch: 63/200, Iter: 21/98, Loss: 1.6601886749267578
# Jan12_04-44-38, Epoch: 63/200, Iter: 41/98, Loss: 1.4748423099517822
# Jan12_04-44-47, Epoch: 63/200, Iter: 61/98, Loss: 1.5001617670059204
# Jan12_04-44-55, Epoch: 63/200, Iter: 81/98, Loss: 1.3461575508117676
# Jan12_04-45-07, Epoch: 64/200, Iter: 1/98, Loss: 1.502321720123291
# Jan12_04-45-15, Epoch: 64/200, Iter: 21/98, Loss: 1.0666333436965942
# Jan12_04-45-23, Epoch: 64/200, Iter: 41/98, Loss: 1.4455103874206543
# Jan12_04-45-32, Epoch: 64/200, Iter: 61/98, Loss: 1.3492757081985474
# Jan12_04-45-40, Epoch: 64/200, Iter: 81/98, Loss: 1.7518699169158936
# Jan12_04-45-52, Epoch: 65/200, Iter: 1/98, Loss: 1.475380778312683
# Jan12_04-46-01, Epoch: 65/200, Iter: 21/98, Loss: 1.3719147443771362
# Jan12_04-46-09, Epoch: 65/200, Iter: 41/98, Loss: 1.4600962400436401
# Jan12_04-46-17, Epoch: 65/200, Iter: 61/98, Loss: 1.5546534061431885
# Jan12_04-46-26, Epoch: 65/200, Iter: 81/98, Loss: 1.480076551437378
# Jan12_04-46-37, Epoch: 66/200, Iter: 1/98, Loss: 1.7025036811828613
# Jan12_04-46-46, Epoch: 66/200, Iter: 21/98, Loss: 1.4393237829208374
# Jan12_04-46-54, Epoch: 66/200, Iter: 41/98, Loss: 1.6216564178466797
# Jan12_04-47-02, Epoch: 66/200, Iter: 61/98, Loss: 1.4338674545288086
# Jan12_04-47-11, Epoch: 66/200, Iter: 81/98, Loss: 1.5596528053283691
# Jan12_04-47-23, Epoch: 67/200, Iter: 1/98, Loss: 1.5080307722091675
# Jan12_04-47-31, Epoch: 67/200, Iter: 21/98, Loss: 1.2259398698806763
# Jan12_04-47-40, Epoch: 67/200, Iter: 41/98, Loss: 1.4127583503723145
# Jan12_04-47-48, Epoch: 67/200, Iter: 61/98, Loss: 1.2147469520568848
# Jan12_04-47-56, Epoch: 67/200, Iter: 81/98, Loss: 1.3284049034118652
# Jan12_04-48-08, Epoch: 68/200, Iter: 1/98, Loss: 1.5069026947021484
# Jan12_04-48-17, Epoch: 68/200, Iter: 21/98, Loss: 1.583094835281372
# Jan12_04-48-25, Epoch: 68/200, Iter: 41/98, Loss: 1.3122687339782715
# Jan12_04-48-33, Epoch: 68/200, Iter: 61/98, Loss: 1.320192813873291
# Jan12_04-48-42, Epoch: 68/200, Iter: 81/98, Loss: 1.610400676727295
# Jan12_04-48-55, Epoch: 69/200, Iter: 1/98, Loss: 1.8248207569122314
# Jan12_04-49-04, Epoch: 69/200, Iter: 21/98, Loss: 1.4786677360534668
# Jan12_04-49-13, Epoch: 69/200, Iter: 41/98, Loss: 1.3395159244537354
# Jan12_04-49-22, Epoch: 69/200, Iter: 61/98, Loss: 1.3972208499908447
# Jan12_04-49-30, Epoch: 69/200, Iter: 81/98, Loss: 1.5205347537994385
# Jan12_04-49-42, Epoch: 70/200, Iter: 1/98, Loss: 1.4411036968231201
# Jan12_04-49-50, Epoch: 70/200, Iter: 21/98, Loss: 1.5755798816680908
# Jan12_04-49-59, Epoch: 70/200, Iter: 41/98, Loss: 1.7315466403961182
# Jan12_04-50-07, Epoch: 70/200, Iter: 61/98, Loss: 1.6366357803344727
# Jan12_04-50-16, Epoch: 70/200, Iter: 81/98, Loss: 1.5832784175872803
# Jan12_04-50-27, Epoch: 71/200, Iter: 1/98, Loss: 1.4327328205108643
# Jan12_04-50-36, Epoch: 71/200, Iter: 21/98, Loss: 1.3537176847457886
# Jan12_04-50-44, Epoch: 71/200, Iter: 41/98, Loss: 1.5380288362503052
# Jan12_04-50-53, Epoch: 71/200, Iter: 61/98, Loss: 1.5301157236099243
# Jan12_04-51-01, Epoch: 71/200, Iter: 81/98, Loss: 1.512223482131958
# Jan12_04-51-13, Epoch: 72/200, Iter: 1/98, Loss: 1.537644863128662
# Jan12_04-51-21, Epoch: 72/200, Iter: 21/98, Loss: 1.607274055480957
# Jan12_04-51-29, Epoch: 72/200, Iter: 41/98, Loss: 1.3279961347579956
# Jan12_04-51-38, Epoch: 72/200, Iter: 61/98, Loss: 1.6067876815795898
# Jan12_04-51-46, Epoch: 72/200, Iter: 81/98, Loss: 1.7966045141220093
# Jan12_04-51-58, Epoch: 73/200, Iter: 1/98, Loss: 1.4745672941207886
# Jan12_04-52-06, Epoch: 73/200, Iter: 21/98, Loss: 1.6222102642059326
# Jan12_04-52-15, Epoch: 73/200, Iter: 41/98, Loss: 1.7058395147323608
# Jan12_04-52-23, Epoch: 73/200, Iter: 61/98, Loss: 1.589369773864746
# Jan12_04-52-32, Epoch: 73/200, Iter: 81/98, Loss: 1.3006335496902466
# Jan12_04-52-43, Epoch: 74/200, Iter: 1/98, Loss: 1.3675227165222168
# Jan12_04-52-51, Epoch: 74/200, Iter: 21/98, Loss: 1.4820793867111206
# Jan12_04-53-00, Epoch: 74/200, Iter: 41/98, Loss: 1.5917942523956299
# Jan12_04-53-08, Epoch: 74/200, Iter: 61/98, Loss: 1.4648405313491821
# Jan12_04-53-17, Epoch: 74/200, Iter: 81/98, Loss: 1.4697375297546387
# Jan12_04-53-28, Epoch: 75/200, Iter: 1/98, Loss: 1.356807827949524
# Jan12_04-53-37, Epoch: 75/200, Iter: 21/98, Loss: 1.6158626079559326
# Jan12_04-53-45, Epoch: 75/200, Iter: 41/98, Loss: 1.5101141929626465
# Jan12_04-53-53, Epoch: 75/200, Iter: 61/98, Loss: 1.5669056177139282
# Jan12_04-54-02, Epoch: 75/200, Iter: 81/98, Loss: 1.6290724277496338
# Jan12_04-54-13, Epoch: 76/200, Iter: 1/98, Loss: 1.4259459972381592
# Jan12_04-54-22, Epoch: 76/200, Iter: 21/98, Loss: 1.4366629123687744
# Jan12_04-54-30, Epoch: 76/200, Iter: 41/98, Loss: 1.5655865669250488
# Jan12_04-54-39, Epoch: 76/200, Iter: 61/98, Loss: 1.647697925567627
# Jan12_04-54-47, Epoch: 76/200, Iter: 81/98, Loss: 1.3543767929077148
# Jan12_04-54-59, Epoch: 77/200, Iter: 1/98, Loss: 1.376699447631836
# Jan12_04-55-07, Epoch: 77/200, Iter: 21/98, Loss: 1.4404972791671753
# Jan12_04-55-16, Epoch: 77/200, Iter: 41/98, Loss: 1.4281272888183594
# Jan12_04-55-24, Epoch: 77/200, Iter: 61/98, Loss: 1.5681936740875244
# Jan12_04-55-33, Epoch: 77/200, Iter: 81/98, Loss: 1.1881479024887085
# Jan12_04-55-44, Epoch: 78/200, Iter: 1/98, Loss: 1.66261625289917
# Jan12_04-55-53, Epoch: 78/200, Iter: 21/98, Loss: 1.5775117874145508
# Jan12_04-56-01, Epoch: 78/200, Iter: 41/98, Loss: 1.6307440996170044
# Jan12_04-56-10, Epoch: 78/200, Iter: 61/98, Loss: 1.6415736675262451
# Jan12_04-56-18, Epoch: 78/200, Iter: 81/98, Loss: 1.6496243476867676
# Jan12_04-56-30, Epoch: 79/200, Iter: 1/98, Loss: 1.4988067150115967
# Jan12_04-56-38, Epoch: 79/200, Iter: 21/98, Loss: 1.582231044769287
# Jan12_04-56-47, Epoch: 79/200, Iter: 41/98, Loss: 1.4472037553787231
# Jan12_04-56-55, Epoch: 79/200, Iter: 61/98, Loss: 1.0081499814987183
# Jan12_04-57-04, Epoch: 79/200, Iter: 81/98, Loss: 1.4255051612854004
# Jan12_04-57-15, Epoch: 80/200, Iter: 1/98, Loss: 1.1041899919509888
# Jan12_04-57-23, Epoch: 80/200, Iter: 21/98, Loss: 1.464613437652588
# Jan12_04-57-32, Epoch: 80/200, Iter: 41/98, Loss: 1.4559907913208008
# Jan12_04-57-40, Epoch: 80/200, Iter: 61/98, Loss: 1.435436487197876
# Jan12_04-57-49, Epoch: 80/200, Iter: 81/98, Loss: 1.322434902191162
# Jan12_04-58-01, Epoch: 81/200, Iter: 1/98, Loss: 1.8562995195388794
# Jan12_04-58-09, Epoch: 81/200, Iter: 21/98, Loss: 1.9106276035308838
# Jan12_04-58-17, Epoch: 81/200, Iter: 41/98, Loss: 1.4742510318756104
# Jan12_04-58-26, Epoch: 81/200, Iter: 61/98, Loss: 1.6845438480377197
# Jan12_04-58-34, Epoch: 81/200, Iter: 81/98, Loss: 1.2179126739501953
# Jan12_04-58-46, Epoch: 82/200, Iter: 1/98, Loss: 1.2546792030334473
# Jan12_04-58-54, Epoch: 82/200, Iter: 21/98, Loss: 1.6574901342391968
# Jan12_04-59-03, Epoch: 82/200, Iter: 41/98, Loss: 1.4421513080596924
# Jan12_04-59-11, Epoch: 82/200, Iter: 61/98, Loss: 1.6346087455749512
# Jan12_04-59-20, Epoch: 82/200, Iter: 81/98, Loss: 1.4105889797210693
# Jan12_04-59-32, Epoch: 83/200, Iter: 1/98, Loss: 1.5175013542175293
# Jan12_04-59-40, Epoch: 83/200, Iter: 21/98, Loss: 1.2965749502182007
# Jan12_04-59-48, Epoch: 83/200, Iter: 41/98, Loss: 1.385990858078003
# Jan12_04-59-57, Epoch: 83/200, Iter: 61/98, Loss: 1.5119132995605469
# Jan12_05-00-05, Epoch: 83/200, Iter: 81/98, Loss: 1.4105805158615112
# Jan12_05-00-17, Epoch: 84/200, Iter: 1/98, Loss: 1.4970875978469849
# Jan12_05-00-25, Epoch: 84/200, Iter: 21/98, Loss: 1.4398207664489746
# Jan12_05-00-34, Epoch: 84/200, Iter: 41/98, Loss: 1.566573143005371
# Jan12_05-00-42, Epoch: 84/200, Iter: 61/98, Loss: 1.1532411575317383
# Jan12_05-00-51, Epoch: 84/200, Iter: 81/98, Loss: 1.688352346420288
# Jan12_05-01-02, Epoch: 85/200, Iter: 1/98, Loss: 1.415069818496704
# Jan12_05-01-11, Epoch: 85/200, Iter: 21/98, Loss: 1.5318734645843506
# Jan12_05-01-19, Epoch: 85/200, Iter: 41/98, Loss: 1.3323984146118164
# Jan12_05-01-27, Epoch: 85/200, Iter: 61/98, Loss: 1.3079912662506104
# Jan12_05-01-36, Epoch: 85/200, Iter: 81/98, Loss: 1.7714807987213135
# Jan12_05-01-47, Epoch: 86/200, Iter: 1/98, Loss: 1.5681673288345337
# Jan12_05-01-56, Epoch: 86/200, Iter: 21/98, Loss: 1.3189811706542969
# Jan12_05-02-04, Epoch: 86/200, Iter: 41/98, Loss: 1.5296465158462524
# Jan12_05-02-12, Epoch: 86/200, Iter: 61/98, Loss: 1.5868053436279297
# Jan12_05-02-21, Epoch: 86/200, Iter: 81/98, Loss: 1.5003033876419067
# Jan12_05-02-33, Epoch: 87/200, Iter: 1/98, Loss: 1.8302463293075562
# Jan12_05-02-41, Epoch: 87/200, Iter: 21/98, Loss: 1.4684474468231201
# Jan12_05-02-49, Epoch: 87/200, Iter: 41/98, Loss: 1.3722648620605469
# Jan12_05-02-58, Epoch: 87/200, Iter: 61/98, Loss: 1.5568749904632568
# Jan12_05-03-06, Epoch: 87/200, Iter: 81/98, Loss: 1.5417717695236206
# Jan12_05-03-18, Epoch: 88/200, Iter: 1/98, Loss: 1.263217568397522
# Jan12_05-03-26, Epoch: 88/200, Iter: 21/98, Loss: 1.557987928390503
# Jan12_05-03-34, Epoch: 88/200, Iter: 41/98, Loss: 1.401422142982483
# Jan12_05-03-43, Epoch: 88/200, Iter: 61/98, Loss: 1.13961923122406
# Jan12_05-03-51, Epoch: 88/200, Iter: 81/98, Loss: 1.4640984535217285
# Jan12_05-04-03, Epoch: 89/200, Iter: 1/98, Loss: 1.4786484241485596
# Jan12_05-04-12, Epoch: 89/200, Iter: 21/98, Loss: 1.3458197116851807
# Jan12_05-04-20, Epoch: 89/200, Iter: 41/98, Loss: 1.3700411319732666
# Jan12_05-04-28, Epoch: 89/200, Iter: 61/98, Loss: 1.2350962162017822
# Jan12_05-04-37, Epoch: 89/200, Iter: 81/98, Loss: 1.5421075820922852
# Jan12_05-04-48, Epoch: 90/200, Iter: 1/98, Loss: 1.5942435264587402
# Jan12_05-04-57, Epoch: 90/200, Iter: 21/98, Loss: 1.2993378639221191
# Jan12_05-05-05, Epoch: 90/200, Iter: 41/98, Loss: 1.3902828693389893
# Jan12_05-05-13, Epoch: 90/200, Iter: 61/98, Loss: 1.2479524612426758
# Jan12_05-05-22, Epoch: 90/200, Iter: 81/98, Loss: 1.6147418022155762
# Jan12_05-05-34, Epoch: 91/200, Iter: 1/98, Loss: 1.6356184482574463
# Jan12_05-05-42, Epoch: 91/200, Iter: 21/98, Loss: 1.4751439094543457
# Jan12_05-05-50, Epoch: 91/200, Iter: 41/98, Loss: 1.6190171241760254
# Jan12_05-05-59, Epoch: 91/200, Iter: 61/98, Loss: 1.6441142559051514
# Jan12_05-06-07, Epoch: 91/200, Iter: 81/98, Loss: 1.5555782318115234
# Jan12_05-06-19, Epoch: 92/200, Iter: 1/98, Loss: 1.2873945236206055
# Jan12_05-06-27, Epoch: 92/200, Iter: 21/98, Loss: 1.745201587677002
# Jan12_05-06-35, Epoch: 92/200, Iter: 41/98, Loss: 1.5134918689727783
# Jan12_05-06-44, Epoch: 92/200, Iter: 61/98, Loss: 1.7146565914154053
# Jan12_05-06-52, Epoch: 92/200, Iter: 81/98, Loss: 1.2708079814910889
# Jan12_05-07-04, Epoch: 93/200, Iter: 1/98, Loss: 1.0425405502319336
# Jan12_05-07-12, Epoch: 93/200, Iter: 21/98, Loss: 1.268076777458191
# Jan12_05-07-21, Epoch: 93/200, Iter: 41/98, Loss: 1.5945614576339722
# Jan12_05-07-29, Epoch: 93/200, Iter: 61/98, Loss: 1.5226831436157227
# Jan12_05-07-37, Epoch: 93/200, Iter: 81/98, Loss: 1.6209886074066162
# Jan12_05-07-49, Epoch: 94/200, Iter: 1/98, Loss: 1.1914476156234741
# Jan12_05-07-57, Epoch: 94/200, Iter: 21/98, Loss: 1.2970616817474365
# Jan12_05-08-05, Epoch: 94/200, Iter: 41/98, Loss: 1.367552638053894
# Jan12_05-08-14, Epoch: 94/200, Iter: 61/98, Loss: 1.6752632856369019
# Jan12_05-08-22, Epoch: 94/200, Iter: 81/98, Loss: 1.4616655111312866
# Jan12_05-08-34, Epoch: 95/200, Iter: 1/98, Loss: 1.2440340518951416
# Jan12_05-08-42, Epoch: 95/200, Iter: 21/98, Loss: 1.327988862991333
# Jan12_05-08-51, Epoch: 95/200, Iter: 41/98, Loss: 1.6430530548095703
# Jan12_05-08-59, Epoch: 95/200, Iter: 61/98, Loss: 1.5289978981018066
# Jan12_05-09-07, Epoch: 95/200, Iter: 81/98, Loss: 1.5943808555603027
# Jan12_05-09-19, Epoch: 96/200, Iter: 1/98, Loss: 1.3832449913024902
# Jan12_05-09-27, Epoch: 96/200, Iter: 21/98, Loss: 1.3857886791229248
# Jan12_05-09-35, Epoch: 96/200, Iter: 41/98, Loss: 1.56984543800354
# Jan12_05-09-44, Epoch: 96/200, Iter: 61/98, Loss: 1.640238881111145
# Jan12_05-09-52, Epoch: 96/200, Iter: 81/98, Loss: 1.2087277173995972
# Jan12_05-10-04, Epoch: 97/200, Iter: 1/98, Loss: 1.2576701641082764
# Jan12_05-10-12, Epoch: 97/200, Iter: 21/98, Loss: 1.68449068069458
# Jan12_05-10-21, Epoch: 97/200, Iter: 41/98, Loss: 1.6214494705200195
# Jan12_05-10-29, Epoch: 97/200, Iter: 61/98, Loss: 1.5096291303634644
# Jan12_05-10-37, Epoch: 97/200, Iter: 81/98, Loss: 1.4950369596481323
# Jan12_05-10-49, Epoch: 98/200, Iter: 1/98, Loss: 1.237439751625061
# Jan12_05-10-57, Epoch: 98/200, Iter: 21/98, Loss: 1.4759466648101807
# Jan12_05-11-06, Epoch: 98/200, Iter: 41/98, Loss: 1.536781907081604
# Jan12_05-11-14, Epoch: 98/200, Iter: 61/98, Loss: 1.3398423194885254
# Jan12_05-11-22, Epoch: 98/200, Iter: 81/98, Loss: 1.3661754131317139
# Jan12_05-11-34, Epoch: 99/200, Iter: 1/98, Loss: 1.4123748540878296
# Jan12_05-11-43, Epoch: 99/200, Iter: 21/98, Loss: 1.6708061695098877
# Jan12_05-11-51, Epoch: 99/200, Iter: 41/98, Loss: 1.5672732591629028
# Jan12_05-11-59, Epoch: 99/200, Iter: 61/98, Loss: 1.6438684463500977
# Jan12_05-12-08, Epoch: 99/200, Iter: 81/98, Loss: 1.6547101736068726
# Jan12_05-12-19, Epoch: 100/200, Iter: 1/98, Loss: 1.6168302297592163
# Jan12_05-12-28, Epoch: 100/200, Iter: 21/98, Loss: 1.5977133512496948
# Jan12_05-12-36, Epoch: 100/200, Iter: 41/98, Loss: 1.3195546865463257
